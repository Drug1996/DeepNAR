# %%
import pickle
import numpy as np
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from network import BiRNN, RNN, CNN, AttenBiRNN
from visualization import variance_and_bias_analysis, plot_confusion_matrix, show, save, data_visual
from data_optimization import dimension_reduce, normalization
from data_augmentation import crop
import datetime

# %%
# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# device = torch.device('cpu')

# Hyper-parameters
sequence_length = 0  # this parameter will be renewed in 'dataloader' function
input_size = 36  # including 6 channels of 6 IMU sensors, totally 36 channels
hidden_size = 256  # parameters for LSTM (Long Short Term Memory)
num_layers = 2  # the depth of Deep-RNNs
num_classes = 4
batch_size = 48
num_epochs = 30
learning_rate = 0.01

# Test parameters
RANDOM_SEED_NUM = 0
TRIALS_NUM = 5
LABELS = ['right_standing', 'wrong_standing', 'right_turning', 'wrong_turning']
DATASET_NAME = 'dataset.pkl'


def data_load():

    dataset_name0 = 'lin'
    dataset_name1 = 'zhong'
    actions = LABELS
    pkl_file = open(DATASET_NAME, 'rb')
    dataset = pickle.load(pkl_file)
    pkl_file.close()
    dataset0 = dataset[dataset_name0]
    dataset1 = dataset[dataset_name1]

    # get longest length among different actions
    max_t = max(dataset0['length_range'][1], dataset1['length_range'][1])
    global sequence_length
    sequence_length = max_t  # the longest length of sample

    # divide the dataset into train set, dev set and test set
    x_train, y_train, x_dev, y_dev, x_test, y_test = [], [], [], [], [], []
    for label, action in enumerate(actions):

        # lin
        labels = [label] * len(dataset0[action])
        temp_train_x, temp_test_x, temp_train_y, temp_test_y = \
            train_test_split(dataset0[action], labels, test_size=0.4, random_state=RANDOM_SEED_NUM)
        x_train += temp_train_x
        y_train += temp_train_y
        temp_train_x, temp_test_x, temp_train_y, temp_test_y = \
            train_test_split(temp_test_x, temp_test_y, test_size=0.5, random_state=RANDOM_SEED_NUM)
        x_dev += temp_train_x
        y_dev += temp_train_y
        x_test += temp_test_x
        y_test +=temp_test_y

        # zhong
        labels = [label] * len(dataset1[action])
        temp_train_x, temp_test_x, temp_train_y, temp_test_y = \
            train_test_split(dataset1[action], labels, test_size=0.4, random_state=RANDOM_SEED_NUM)
        x_train += temp_train_x
        y_train += temp_train_y
        temp_train_x, temp_test_x, temp_train_y, temp_test_y = \
            train_test_split(temp_test_x, temp_test_y, test_size=0.5, random_state=RANDOM_SEED_NUM)
        x_dev += temp_train_x
        y_dev += temp_train_y
        x_test += temp_test_x
        y_test += temp_test_y

    # data augmentation
    x_train, y_train = crop(x_train, y_train)

    # pad the data samples
    for i in range(len(x_train)):
        x_train[i] = \
            np.pad(x_train[i][:, 1:], ((0, max_t - x_train[i].shape[0]), (0, 0)), 'constant', constant_values=0)
    for i in range(len(x_dev)):
        x_dev[i] = \
            np.pad(x_dev[i][:, 1:], ((0, max_t - x_dev[i].shape[0]), (0, 0)), 'constant', constant_values=0)
    for i in range(len(x_test)):
        x_test[i] = \
            np.pad(x_test[i][:, 1:], ((0, max_t - x_test[i].shape[0]), (0, 0)), 'constant', constant_values=0)

    # shuffle
    x_train, y_train = shuffle(x_train, y_train, random_state=RANDOM_SEED_NUM+1)
    x_dev, y_dev = shuffle(x_dev, y_dev, random_state=RANDOM_SEED_NUM+2)
    x_test, y_test = shuffle(x_test, y_test, random_state=RANDOM_SEED_NUM+3)

    # change dataset's data format
    x_train, y_train = \
        torch.from_numpy(np.array(x_train)).type(torch.FloatTensor),\
        torch.from_numpy(np.array(y_train)).type(torch.LongTensor)
    x_dev, y_dev = \
        torch.from_numpy(np.array(x_dev)).type(torch.FloatTensor),\
        torch.from_numpy(np.array(y_dev)).type(torch.LongTensor)
    x_test, y_test = \
        torch.from_numpy(np.array(x_test)).type(torch.FloatTensor),\
        torch.from_numpy(np.array(y_test)).type(torch.LongTensor)

    return x_train, y_train, x_dev, y_dev, x_test, y_test


def training_model(num):
    # torch.manual_seed(RANDOM_SEED_NUM)

    # Load the dataset
    X_training, Y_training, X_dev, Y_dev, X_test, Y_test = data_load()
    
    # Record losses, accuracies and labels for drawing analysis figures
    training_losses = []
    test_accuracies = []
    y_true = []
    y_pred = []

    # Create the model
    model = AttenBiRNN(input_size, hidden_size, num_layers, num_classes, sequence_length).to(device)

    # Loss and optimizer
    criterion = nn.CrossEntropyLoss() # Cross Entropy Loss funtion
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate) # Adam optimzer

    # Create Pytorch's dataloader for training, valid and test dataset
    train_dataset = TensorDataset(X_training, Y_training)
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    dev_dataset = TensorDataset(X_dev, Y_dev)
    dev_loader = DataLoader(dev_dataset)
    test_dataset = TensorDataset(X_test, Y_test)
    test_loader = DataLoader(test_dataset)

    # Start training the model
    for epoch in range(num_epochs):
        for i, (inputs, labels) in enumerate(train_loader):
            inputs = inputs.reshape(-1, sequence_length, input_size).to(device)
            labels = labels.reshape(-1).to(device)
            # Forward pass
            outputs = model(inputs)
            training_loss = criterion(outputs, labels)
            # Backward and optimize
            optimizer.zero_grad()
            training_loss.backward()
            optimizer.step()
            
        # Print information, collect the training loss and valid accuracy for every 2 epoches
        if (epoch + 1) % 2 == 0:
            # Print information
            print('Test [{}], Epoch [{}/{}], Loss: {:.4f}'
                  .format(num+1, epoch + 1, num_epochs, training_loss.item()))
            # Get the value of loss
            training_losses.append(training_loss.item())
            # Test the model on valid dataset
            with torch.no_grad():
                y_true = []
                y_pred = []
                correct = 0
                total = 0
                for j, (inputs, labels) in enumerate(dev_loader):
                    inputs = inputs.reshape(-1, sequence_length, input_size).to(device)
                    labels = labels.reshape(-1).to(device)
                    outputs = model(inputs)
                    _, predicted = torch.max(outputs.data, 1)
                    total += labels.size(0)
                    correct += (predicted == labels).sum().item()
                    y_true.append(labels.item())
                    y_pred.append(predicted.item())
                test_accuracies.append(correct/total)

    # Print accuracy of the model
    accuracy = test_accuracies[-1]*100
    print('Dev accuracy of the No.{} model on dev action samples: {} %'.format(num+1, accuracy))

    # Show or save the graph of variance and bias analysis, and confusion matrix graph
    variance_and_bias_analysis([training_losses], [test_accuracies])
    save('trials' + str(num+1) + '_loss_accuracy' + '.png')
    plot_confusion_matrix([y_true], [y_pred], LABELS)
    save('trials_' + str(num+1) + '_confusion_matrix' + '.png')

    return accuracy, model, test_loader


def test_model(model, test_loader):
    # Test the model on test set
    with torch.no_grad():
        y_true = []
        y_pred = []
        correct = 0
        total = 0
        for i, (inputs, labels) in enumerate(test_loader):
            inputs = inputs.reshape(-1, sequence_length, input_size).to(device)
            labels = labels.reshape(-1).to(device)
            outputs = model(inputs)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            y_true.append(labels.item())
            y_pred.append(predicted.item())
        
        accuracy = (correct/total)*100
        print('Final accuracy is {} %'.format(accuracy))
        plot_confusion_matrix([y_true], [y_pred], LABELS)
        save('test_confusion_matrix' + '.png')

    # Save the modal checkpoint
    torch.save(model.state_dict(), 'DeepNAR_model.ckpt')
    
    return accuracy


def main(num):
    accuracylist = []
    modellist = []
    for i in range(num):
        accuracy, model, test_loader = training_model(i)
        accuracylist.append(accuracy)
        modellist.append(model)
    index = accuracylist.index(max(accuracylist))
    print('Choose No.{} model as test model with {} % Dev accuracy.'.format(index+1, max(accuracylist)))
    best_model = modellist[index]
    test_accuracy = test_model(best_model, test_loader)
              
    return test_accuracy

# %%
test_num = 5
test_accuracies = []
start = datetime.datetime.now()
for i in range(test_num):
    accuracy = main(num=TRIALS_NUM)
    test_accuracies.append(accuracy)
end = datetime.datetime.now()
print('[Cost Time]: total - {}s, each - {}s'.format(end-start, (end-start)/test_num))
print('{} times average accuracy - {}%'.format(test_num, np.mean(test_accuracies)))
# Out:
# Test [1], Epoch [2/30], Loss: 0.4321
# Test [1], Epoch [4/30], Loss: 0.2688
# Test [1], Epoch [6/30], Loss: 0.0022
# Test [1], Epoch [8/30], Loss: 0.0202
# Test [1], Epoch [10/30], Loss: 0.0010
# Test [1], Epoch [12/30], Loss: 0.0005
# Test [1], Epoch [14/30], Loss: 0.0001
# Test [1], Epoch [16/30], Loss: 0.0001
# Test [1], Epoch [18/30], Loss: 0.0000
# Test [1], Epoch [20/30], Loss: 0.0001
# Test [1], Epoch [22/30], Loss: 0.0000
# Test [1], Epoch [24/30], Loss: 0.0000
# Test [1], Epoch [26/30], Loss: 0.0000
# Test [1], Epoch [28/30], Loss: 0.0000
# Test [1], Epoch [30/30], Loss: 0.0000
# Dev accuracy of the No.1 model on dev action samples: 96.875 %
# Test [2], Epoch [2/30], Loss: 0.4298
# Test [2], Epoch [4/30], Loss: 0.2882
# Test [2], Epoch [6/30], Loss: 0.0276
# Test [2], Epoch [8/30], Loss: 0.0006
# Test [2], Epoch [10/30], Loss: 0.0001
# Test [2], Epoch [12/30], Loss: 0.0001
# Test [2], Epoch [14/30], Loss: 0.0000
# Test [2], Epoch [16/30], Loss: 0.0000
# Test [2], Epoch [18/30], Loss: 0.0000
# Test [2], Epoch [20/30], Loss: 0.0000
# Test [2], Epoch [22/30], Loss: 0.0000
# Test [2], Epoch [24/30], Loss: 0.0000
# Test [2], Epoch [26/30], Loss: 0.0000
# Test [2], Epoch [28/30], Loss: 0.0000
# Test [2], Epoch [30/30], Loss: 0.0000
# Dev accuracy of the No.2 model on dev action samples: 100.0 %
# Test [3], Epoch [2/30], Loss: 0.4049
# Test [3], Epoch [4/30], Loss: 0.2195
# Test [3], Epoch [6/30], Loss: 0.0013
# Test [3], Epoch [8/30], Loss: 0.0015
# Test [3], Epoch [10/30], Loss: 0.0011
# Test [3], Epoch [12/30], Loss: 0.4256
# Test [3], Epoch [14/30], Loss: 0.2065
# Test [3], Epoch [16/30], Loss: 0.0025
# Test [3], Epoch [18/30], Loss: 0.0001
# Test [3], Epoch [20/30], Loss: 0.0001
# Test [3], Epoch [22/30], Loss: 0.0000
# Test [3], Epoch [24/30], Loss: 0.0000
# Test [3], Epoch [26/30], Loss: 0.0000
# Test [3], Epoch [28/30], Loss: 0.0000
# Test [3], Epoch [30/30], Loss: 0.0000
# Dev accuracy of the No.3 model on dev action samples: 87.5 %
# Test [4], Epoch [2/30], Loss: 0.3307
# Test [4], Epoch [4/30], Loss: 0.3376
# Test [4], Epoch [6/30], Loss: 0.1329
# Test [4], Epoch [8/30], Loss: 0.2564
# Test [4], Epoch [10/30], Loss: 0.0252
# Test [4], Epoch [12/30], Loss: 0.0006
# Test [4], Epoch [14/30], Loss: 0.0000
# Test [4], Epoch [16/30], Loss: 0.0001
# Test [4], Epoch [18/30], Loss: 0.0001
# Test [4], Epoch [20/30], Loss: 0.0000
# Test [4], Epoch [22/30], Loss: 0.0000
# Test [4], Epoch [24/30], Loss: 0.0000
# Test [4], Epoch [26/30], Loss: 0.0000
# Test [4], Epoch [28/30], Loss: 0.0000
# Test [4], Epoch [30/30], Loss: 0.0000
# Dev accuracy of the No.4 model on dev action samples: 100.0 %
# Test [5], Epoch [2/30], Loss: 0.3700
# Test [5], Epoch [4/30], Loss: 0.3032
# Test [5], Epoch [6/30], Loss: 0.0983
# Test [5], Epoch [8/30], Loss: 0.0324
# Test [5], Epoch [10/30], Loss: 0.0019
# Test [5], Epoch [12/30], Loss: 0.0003
# Test [5], Epoch [14/30], Loss: 0.0001
# Test [5], Epoch [16/30], Loss: 0.0001
# Test [5], Epoch [18/30], Loss: 0.0000
# Test [5], Epoch [20/30], Loss: 0.0000
# Test [5], Epoch [22/30], Loss: 0.0000
# Test [5], Epoch [24/30], Loss: 0.0000
# Test [5], Epoch [26/30], Loss: 0.0000
# Test [5], Epoch [28/30], Loss: 0.0000
# Test [5], Epoch [30/30], Loss: 0.0000
# Dev accuracy of the No.5 model on dev action samples: 87.5 %
# Choose No.2 model as test model with 100.0 % Dev accuracy.
# Final accuracy is 90.625 %
# Test [1], Epoch [2/30], Loss: 0.3960
# Test [1], Epoch [4/30], Loss: 0.2855
# Test [1], Epoch [6/30], Loss: 0.0229
# Test [1], Epoch [8/30], Loss: 0.0023
# Test [1], Epoch [10/30], Loss: 0.0014
# Test [1], Epoch [12/30], Loss: 0.0001
# Test [1], Epoch [14/30], Loss: 0.0000
# Test [1], Epoch [16/30], Loss: 0.0000
# Test [1], Epoch [18/30], Loss: 0.0000
# Test [1], Epoch [20/30], Loss: 0.0000
# Test [1], Epoch [22/30], Loss: 0.0000
# Test [1], Epoch [24/30], Loss: 0.0000
# Test [1], Epoch [26/30], Loss: 0.0000
# Test [1], Epoch [28/30], Loss: 0.0000
# Test [1], Epoch [30/30], Loss: 0.0000
# Dev accuracy of the No.1 model on dev action samples: 90.625 %
# Test [2], Epoch [2/30], Loss: 0.5563
# Test [2], Epoch [4/30], Loss: 0.0270
# Test [2], Epoch [6/30], Loss: 0.0002
# Test [2], Epoch [8/30], Loss: 0.0967
# Test [2], Epoch [10/30], Loss: 0.2660
# Test [2], Epoch [12/30], Loss: 0.0019
# Test [2], Epoch [14/30], Loss: 0.0003
# Test [2], Epoch [16/30], Loss: 0.0002
# Test [2], Epoch [18/30], Loss: 0.0001
# Test [2], Epoch [20/30], Loss: 0.0000
# Test [2], Epoch [22/30], Loss: 0.0000
# Test [2], Epoch [24/30], Loss: 0.0000
# Test [2], Epoch [26/30], Loss: 0.0000
# Test [2], Epoch [28/30], Loss: 0.0000
# Test [2], Epoch [30/30], Loss: 0.0000
# Dev accuracy of the No.2 model on dev action samples: 93.75 %
# Test [3], Epoch [2/30], Loss: 0.4222
# Test [3], Epoch [4/30], Loss: 0.2969
# Test [3], Epoch [6/30], Loss: 0.0065
# Test [3], Epoch [8/30], Loss: 0.0020
# Test [3], Epoch [10/30], Loss: 0.0000
# Test [3], Epoch [12/30], Loss: 0.0000
# Test [3], Epoch [14/30], Loss: 0.0000
# Test [3], Epoch [16/30], Loss: 0.0000
# Test [3], Epoch [18/30], Loss: 0.0000
# Test [3], Epoch [20/30], Loss: 0.0000
# Test [3], Epoch [22/30], Loss: 0.0000
# Test [3], Epoch [24/30], Loss: 0.0000
# Test [3], Epoch [26/30], Loss: 0.0000
# Test [3], Epoch [28/30], Loss: 0.0000
# Test [3], Epoch [30/30], Loss: 0.0000
# Dev accuracy of the No.3 model on dev action samples: 93.75 %
# Test [4], Epoch [2/30], Loss: 0.4734
# Test [4], Epoch [4/30], Loss: 0.3262
# Test [4], Epoch [6/30], Loss: 0.0533
# Test [4], Epoch [8/30], Loss: 0.0071
# Test [4], Epoch [10/30], Loss: 0.0232
# Test [4], Epoch [12/30], Loss: 0.0239
# Test [4], Epoch [14/30], Loss: 0.0031
# Test [4], Epoch [16/30], Loss: 0.0003
# Test [4], Epoch [18/30], Loss: 0.0002
# Test [4], Epoch [20/30], Loss: 0.0002
# Test [4], Epoch [22/30], Loss: 0.0001
# Test [4], Epoch [24/30], Loss: 0.0001
# Test [4], Epoch [26/30], Loss: 0.0001
# Test [4], Epoch [28/30], Loss: 0.0001
# Test [4], Epoch [30/30], Loss: 0.0000
# Dev accuracy of the No.4 model on dev action samples: 96.875 %
# Test [5], Epoch [2/30], Loss: 0.5718
# Test [5], Epoch [4/30], Loss: 0.4225
# Test [5], Epoch [6/30], Loss: 0.3558
# Test [5], Epoch [8/30], Loss: 0.0189
# Test [5], Epoch [10/30], Loss: 0.0004
# Test [5], Epoch [12/30], Loss: 0.0005
# Test [5], Epoch [14/30], Loss: 0.0001
# Test [5], Epoch [16/30], Loss: 0.0001
# Test [5], Epoch [18/30], Loss: 0.0001
# Test [5], Epoch [20/30], Loss: 0.0001
# Test [5], Epoch [22/30], Loss: 0.0001
# Test [5], Epoch [24/30], Loss: 0.0000
# Test [5], Epoch [26/30], Loss: 0.0000
# Test [5], Epoch [28/30], Loss: 0.0000
# Test [5], Epoch [30/30], Loss: 0.0000
# Dev accuracy of the No.5 model on dev action samples: 90.625 %
# Choose No.4 model as test model with 96.875 % Dev accuracy.
# Final accuracy is 93.75 %
# Test [1], Epoch [2/30], Loss: 1.0247
# Test [1], Epoch [4/30], Loss: 0.4633
# Test [1], Epoch [6/30], Loss: 0.1746
# Test [1], Epoch [8/30], Loss: 0.0038
# Test [1], Epoch [10/30], Loss: 0.0003
# Test [1], Epoch [12/30], Loss: 0.0001
# Test [1], Epoch [14/30], Loss: 0.0001
# Test [1], Epoch [16/30], Loss: 0.0001
# Test [1], Epoch [18/30], Loss: 0.0001
# Test [1], Epoch [20/30], Loss: 0.0001
# Test [1], Epoch [22/30], Loss: 0.0000
# Test [1], Epoch [24/30], Loss: 0.0000
# Test [1], Epoch [26/30], Loss: 0.0000
# Test [1], Epoch [28/30], Loss: 0.0000
# Test [1], Epoch [30/30], Loss: 0.0000
# Dev accuracy of the No.1 model on dev action samples: 93.75 %
# Test [2], Epoch [2/30], Loss: 0.2848
# Test [2], Epoch [4/30], Loss: 0.1095
# Test [2], Epoch [6/30], Loss: 0.0006
# Test [2], Epoch [8/30], Loss: 0.0002
# Test [2], Epoch [10/30], Loss: 0.0000
# Test [2], Epoch [12/30], Loss: 0.0000
# Test [2], Epoch [14/30], Loss: 0.0000
# Test [2], Epoch [16/30], Loss: 0.0000
# Test [2], Epoch [18/30], Loss: 0.0000
# Test [2], Epoch [20/30], Loss: 0.0000
# Test [2], Epoch [22/30], Loss: 0.0000
# Test [2], Epoch [24/30], Loss: 0.0000
# Test [2], Epoch [26/30], Loss: 0.0000
# Test [2], Epoch [28/30], Loss: 0.0000
# Test [2], Epoch [30/30], Loss: 0.0000
# Dev accuracy of the No.2 model on dev action samples: 96.875 %
# Test [3], Epoch [2/30], Loss: 0.5087
# Test [3], Epoch [4/30], Loss: 0.0033
# Test [3], Epoch [6/30], Loss: 0.0003
# Test [3], Epoch [8/30], Loss: 0.0000
# Test [3], Epoch [10/30], Loss: 0.0000
# Test [3], Epoch [12/30], Loss: 0.0000
# Test [3], Epoch [14/30], Loss: 0.0000
# Test [3], Epoch [16/30], Loss: 0.0000
# Test [3], Epoch [18/30], Loss: 0.0000
# Test [3], Epoch [20/30], Loss: 0.0000
# Test [3], Epoch [22/30], Loss: 0.0000
# Test [3], Epoch [24/30], Loss: 0.0000
# Test [3], Epoch [26/30], Loss: 0.0000
# Test [3], Epoch [28/30], Loss: 0.0000
# Test [3], Epoch [30/30], Loss: 0.0000
# Dev accuracy of the No.3 model on dev action samples: 90.625 %
# Test [4], Epoch [2/30], Loss: 0.4902
# Test [4], Epoch [4/30], Loss: 0.0122
# Test [4], Epoch [6/30], Loss: 0.0020
# Test [4], Epoch [8/30], Loss: 0.0000
# Test [4], Epoch [10/30], Loss: 0.0000
# Test [4], Epoch [12/30], Loss: 0.0000
# Test [4], Epoch [14/30], Loss: 0.0000
# Test [4], Epoch [16/30], Loss: 0.0000
# Test [4], Epoch [18/30], Loss: 0.0000
# Test [4], Epoch [20/30], Loss: 0.0000
# Test [4], Epoch [22/30], Loss: 0.0000
# Test [4], Epoch [24/30], Loss: 0.0000
# Test [4], Epoch [26/30], Loss: 0.0000
# Test [4], Epoch [28/30], Loss: 0.0000
# Test [4], Epoch [30/30], Loss: 0.0000
# Dev accuracy of the No.4 model on dev action samples: 96.875 %
# Test [5], Epoch [2/30], Loss: 0.5974
# Test [5], Epoch [4/30], Loss: 0.1371
# Test [5], Epoch [6/30], Loss: 0.0009
# Test [5], Epoch [8/30], Loss: 0.0000
# Test [5], Epoch [10/30], Loss: 0.0000
# Test [5], Epoch [12/30], Loss: 0.0000
# Test [5], Epoch [14/30], Loss: 0.0000
# Test [5], Epoch [16/30], Loss: 0.0000
# Test [5], Epoch [18/30], Loss: 0.0000
# Test [5], Epoch [20/30], Loss: 0.0000
# Test [5], Epoch [22/30], Loss: 0.0000
# Test [5], Epoch [24/30], Loss: 0.0000
# Test [5], Epoch [26/30], Loss: 0.0000
# Test [5], Epoch [28/30], Loss: 0.0000
# Test [5], Epoch [30/30], Loss: 0.0000
# Dev accuracy of the No.5 model on dev action samples: 93.75 %
# Choose No.2 model as test model with 96.875 % Dev accuracy.
# Final accuracy is 90.625 %
# Test [1], Epoch [2/30], Loss: 0.2880
# Test [1], Epoch [4/30], Loss: 0.1306
# Test [1], Epoch [6/30], Loss: 0.0010
# Test [1], Epoch [8/30], Loss: 0.0001
# Test [1], Epoch [10/30], Loss: 0.0000
# Test [1], Epoch [12/30], Loss: 0.0000
# Test [1], Epoch [14/30], Loss: 0.0000
# Test [1], Epoch [16/30], Loss: 0.0000
# Test [1], Epoch [18/30], Loss: 0.0000
# Test [1], Epoch [20/30], Loss: 0.0000
# Test [1], Epoch [22/30], Loss: 0.0000
# Test [1], Epoch [24/30], Loss: 0.0000
# Test [1], Epoch [26/30], Loss: 0.0000
# Test [1], Epoch [28/30], Loss: 0.0000
# Test [1], Epoch [30/30], Loss: 0.0000
# Dev accuracy of the No.1 model on dev action samples: 100.0 %
# Test [2], Epoch [2/30], Loss: 0.6460
# Test [2], Epoch [4/30], Loss: 0.0427
# Test [2], Epoch [6/30], Loss: 0.0010
# Test [2], Epoch [8/30], Loss: 0.0001
# Test [2], Epoch [10/30], Loss: 0.0000
# Test [2], Epoch [12/30], Loss: 0.0000
# Test [2], Epoch [14/30], Loss: 0.0000
# Test [2], Epoch [16/30], Loss: 0.0000
# Test [2], Epoch [18/30], Loss: 0.0000
# Test [2], Epoch [20/30], Loss: 0.0000
# Test [2], Epoch [22/30], Loss: 0.0000
# Test [2], Epoch [24/30], Loss: 0.0000
# Test [2], Epoch [26/30], Loss: 0.0000
# Test [2], Epoch [28/30], Loss: 0.0000
# Test [2], Epoch [30/30], Loss: 0.0000
# Dev accuracy of the No.2 model on dev action samples: 96.875 %
# Test [3], Epoch [2/30], Loss: 0.6627
# Test [3], Epoch [4/30], Loss: 0.2607
# Test [3], Epoch [6/30], Loss: 0.0490
# Test [3], Epoch [8/30], Loss: 0.1586
# Test [3], Epoch [10/30], Loss: 0.1103
# Test [3], Epoch [12/30], Loss: 0.0466
# Test [3], Epoch [14/30], Loss: 0.0051
# Test [3], Epoch [16/30], Loss: 0.0013
# Test [3], Epoch [18/30], Loss: 0.0003
# Test [3], Epoch [20/30], Loss: 0.0002
# Test [3], Epoch [22/30], Loss: 0.0002
# Test [3], Epoch [24/30], Loss: 0.0002
# Test [3], Epoch [26/30], Loss: 0.0001
# Test [3], Epoch [28/30], Loss: 0.0001
# Test [3], Epoch [30/30], Loss: 0.0002
# Dev accuracy of the No.3 model on dev action samples: 96.875 %
# Test [4], Epoch [2/30], Loss: 0.4972
# Test [4], Epoch [4/30], Loss: 0.2358
# Test [4], Epoch [6/30], Loss: 0.0119
# Test [4], Epoch [8/30], Loss: 0.0011
# Test [4], Epoch [10/30], Loss: 0.0001
# Test [4], Epoch [12/30], Loss: 0.0000
# Test [4], Epoch [14/30], Loss: 0.0000
# Test [4], Epoch [16/30], Loss: 0.0000
# Test [4], Epoch [18/30], Loss: 0.0000
# Test [4], Epoch [20/30], Loss: 0.0000
# Test [4], Epoch [22/30], Loss: 0.0000
# Test [4], Epoch [24/30], Loss: 0.0000
# Test [4], Epoch [26/30], Loss: 0.0000
# Test [4], Epoch [28/30], Loss: 0.0000
# Test [4], Epoch [30/30], Loss: 0.0000
# Dev accuracy of the No.4 model on dev action samples: 93.75 %
# Test [5], Epoch [2/30], Loss: 0.4338
# Test [5], Epoch [4/30], Loss: 0.1155
# Test [5], Epoch [6/30], Loss: 0.0004
# Test [5], Epoch [8/30], Loss: 0.0000
# Test [5], Epoch [10/30], Loss: 0.0000
# Test [5], Epoch [12/30], Loss: 0.0000
# Test [5], Epoch [14/30], Loss: 0.0000
# Test [5], Epoch [16/30], Loss: 0.0000
# Test [5], Epoch [18/30], Loss: 0.0000
# Test [5], Epoch [20/30], Loss: 0.0000
# Test [5], Epoch [22/30], Loss: 0.0000
# Test [5], Epoch [24/30], Loss: 0.0000
# Test [5], Epoch [26/30], Loss: 0.0000
# Test [5], Epoch [28/30], Loss: 0.0000
# Test [5], Epoch [30/30], Loss: 0.0000
# Dev accuracy of the No.5 model on dev action samples: 93.75 %
# Choose No.1 model as test model with 100.0 % Dev accuracy.
# Final accuracy is 93.75 %
# Test [1], Epoch [2/30], Loss: 0.3760
# Test [1], Epoch [4/30], Loss: 0.2674
# Test [1], Epoch [6/30], Loss: 0.0306
# Test [1], Epoch [8/30], Loss: 0.0022
# Test [1], Epoch [10/30], Loss: 0.0004
# Test [1], Epoch [12/30], Loss: 0.0002
# Test [1], Epoch [14/30], Loss: 0.0001
# Test [1], Epoch [16/30], Loss: 0.0000
# Test [1], Epoch [18/30], Loss: 0.0000
# Test [1], Epoch [20/30], Loss: 0.0000
# Test [1], Epoch [22/30], Loss: 0.0000
# Test [1], Epoch [24/30], Loss: 0.0000
# Test [1], Epoch [26/30], Loss: 0.0000
# Test [1], Epoch [28/30], Loss: 0.0000
# Test [1], Epoch [30/30], Loss: 0.0000
# Dev accuracy of the No.1 model on dev action samples: 96.875 %
# Test [2], Epoch [2/30], Loss: 0.6189
# Test [2], Epoch [4/30], Loss: 0.1211
# Test [2], Epoch [6/30], Loss: 0.0017
# Test [2], Epoch [8/30], Loss: 0.0001
# Test [2], Epoch [10/30], Loss: 0.0000
# Test [2], Epoch [12/30], Loss: 0.0000
# Test [2], Epoch [14/30], Loss: 0.0000
# Test [2], Epoch [16/30], Loss: 0.0000
# Test [2], Epoch [18/30], Loss: 0.0000
# Test [2], Epoch [20/30], Loss: 0.0000
# Test [2], Epoch [22/30], Loss: 0.0000
# Test [2], Epoch [24/30], Loss: 0.0000
# Test [2], Epoch [26/30], Loss: 0.0000
# Test [2], Epoch [28/30], Loss: 0.0000
# Test [2], Epoch [30/30], Loss: 0.0000
# Dev accuracy of the No.2 model on dev action samples: 96.875 %
# Test [3], Epoch [2/30], Loss: 0.4700
# Test [3], Epoch [4/30], Loss: 0.3143
# Test [3], Epoch [6/30], Loss: 0.1575
# Test [3], Epoch [8/30], Loss: 0.0014
# Test [3], Epoch [10/30], Loss: 0.0002
# Test [3], Epoch [12/30], Loss: 0.0002
# Test [3], Epoch [14/30], Loss: 0.0000
# Test [3], Epoch [16/30], Loss: 0.0000
# Test [3], Epoch [18/30], Loss: 0.0000
# Test [3], Epoch [20/30], Loss: 0.0000
# Test [3], Epoch [22/30], Loss: 0.0000
# Test [3], Epoch [24/30], Loss: 0.0000
# Test [3], Epoch [26/30], Loss: 0.0000
# Test [3], Epoch [28/30], Loss: 0.0000
# Test [3], Epoch [30/30], Loss: 0.0000
# Dev accuracy of the No.3 model on dev action samples: 90.625 %
# Test [4], Epoch [2/30], Loss: 1.1652
# Test [4], Epoch [4/30], Loss: 0.2920
# Test [4], Epoch [6/30], Loss: 0.0759
# Test [4], Epoch [8/30], Loss: 0.1932
# Test [4], Epoch [10/30], Loss: 0.0777
# Test [4], Epoch [12/30], Loss: 0.0087
# Test [4], Epoch [14/30], Loss: 0.0018
# Test [4], Epoch [16/30], Loss: 0.0004
# Test [4], Epoch [18/30], Loss: 0.0002
# Test [4], Epoch [20/30], Loss: 0.0001
# Test [4], Epoch [22/30], Loss: 0.0001
# Test [4], Epoch [24/30], Loss: 0.0000
# Test [4], Epoch [26/30], Loss: 0.0000
# Test [4], Epoch [28/30], Loss: 0.0000
# Test [4], Epoch [30/30], Loss: 0.0000
# Dev accuracy of the No.4 model on dev action samples: 96.875 %
# Test [5], Epoch [2/30], Loss: 0.5804
# Test [5], Epoch [4/30], Loss: 0.1457
# Test [5], Epoch [6/30], Loss: 0.0039
# Test [5], Epoch [8/30], Loss: 0.0005
# Test [5], Epoch [10/30], Loss: 0.0421
# Test [5], Epoch [12/30], Loss: 0.0044
# Test [5], Epoch [14/30], Loss: 0.0016
# Test [5], Epoch [16/30], Loss: 0.0004
# Test [5], Epoch [18/30], Loss: 0.0003
# Test [5], Epoch [20/30], Loss: 0.0001
# Test [5], Epoch [22/30], Loss: 0.0001
# Test [5], Epoch [24/30], Loss: 0.0001
# Test [5], Epoch [26/30], Loss: 0.0000
# Test [5], Epoch [28/30], Loss: 0.0001
# Test [5], Epoch [30/30], Loss: 0.0001
# Dev accuracy of the No.5 model on dev action samples: 96.875 %
# Choose No.1 model as test model with 96.875 % Dev accuracy.
# Final accuracy is 93.75 %
# [Cost Time]: total - 0:06:54.099929s, each - 0:01:22.819986s
# 5 times average accuracy - 92.5%

# %%
print(test_accuracies)
# Out:
# [90.625, 93.75, 90.625, 93.75, 93.75]
