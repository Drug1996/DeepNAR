# %%
import pickle
import numpy as np
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader
from data_augmentation import crop
import datetime
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Attention layer
class Attention(nn.Module):
    def __init__(self, feature_dim, **kwargs):
        super(Attention, self).__init__(**kwargs)
        self.feature_dim = feature_dim
        weight = torch.zeros(feature_dim, 1).to(device)
        nn.init.kaiming_uniform_(weight)
        self.weight = nn.Parameter(weight)
        
    def forward(self, x):
        # x structure: (batch size, step dim, feature dim)
        feature_dim = self.feature_dim 
        step_dim = x.shape[1] 
        # eij structrue: (batch size, step dim)
        eij = torch.mm(
            x.contiguous().view(-1, feature_dim), 
            self.weight
        ).view(-1, step_dim)
        eij = torch.tanh(eij)
        a = torch.exp(eij)
        a = a / (torch.sum(a, 1, keepdim=True) + 1e-10)
        weighted_input = x * torch.unsqueeze(a, -1)
        
        return torch.sum(weighted_input, 1)

# Attention based bidirectional recurrent neural network (LSTM Cell)
class AttenBiRNN(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, num_classes):
        super(AttenBiRNN, self).__init__()
        self.num_layers = num_layers
        self.lstm_layers = [nn.LSTM(input_size, hidden_size, batch_first=True, bidirectional=True)]   
        self.attention_layers = [Attention(2*hidden_size)]
        for i in range(1, num_layers):
            self.lstm_layers.append(nn.LSTM(2*hidden_size, hidden_size, batch_first=True, bidirectional=True))   
            self.attention_layers.append(Attention(2*hidden_size))
        self.attention_layers.append(Attention(2*hidden_size))
        self.fc = nn.Sequential(
                    nn.Linear(2*hidden_size, 128),
                    nn.ReLU(True),
                    nn.Linear(128, num_classes))

    def forward(self, x):
        a = []
        h = x
        for i in range(self.num_layers):
            # h: tensor of shape (batch_size, seq_length, hidden_size*2)
            h, _ = self.lstm_layers[i](h)
            a_n = self.attention_layers[i](h)
            a.append(a_n)
        a = torch.cat([a_n.unsqueeze(1) for a_n in a], dim=1)
        h = self.attention_layers(a)
        out = self.fc(h)
        return out

# %%
def variance_and_bias_analysis(train_loss, valid_loss, save_name = 'loss_plot.png'):
    fontsize = 20
    fig = plt.figure(figsize=(10,8))
    plt.plot(range(1,len(train_loss)+1),train_loss, label='Training Loss')
    plt.plot(range(1,len(valid_loss)+1),valid_loss,label='Validation Loss')
    # Find position of lowest validation loss
    minposs = valid_loss.index(min(valid_loss))+1 
    plt.axvline(minposs, linestyle='--', color='r',label='Early Stopping Checkpoint')
    plt.xlabel('epochs', fontsize=fontsize)
    plt.ylabel('loss', fontsize=fontsize)
    plt.xticks(fontsize=fontsize)
    plt.yticks(fontsize=fontsize)
    # plt.ylim(0, 0.8) # Consistent scale
    plt.xlim(0, len(train_loss)+1) # Consistent scale
    plt.tight_layout()
    plt.grid(True)
    plt.legend(fontsize=fontsize)
    fig.savefig(save_name, bbox_inches='tight')


def plot_confusion_matrix(y_true, y_pred, labels_name, save_name='confusion_matrix.png'):
    fontsize = 20
    plt.figure(figsize=(10, 8))
    cm = confusion_matrix(y_true=y_true, y_pred=y_pred)
    cm = cm.astype('float')/cm.sum(axis=1)[:, np.newaxis]
    ax = sns.heatmap(cm, annot=True, cmap='Blues',
                    xticklabels=labels_name, yticklabels=labels_name, annot_kws={"size": fontsize})
    ax.set_ylabel('Ground Truth', fontsize=fontsize)
    ax.set_xlabel('Predictions', fontsize=fontsize)
    plt.tight_layout()
    plt.xticks(fontsize=fontsize)
    plt.yticks(fontsize=fontsize)
    plt.savefig(save_name)

# %%
def adjust_learning_rate(optimizer, lr):
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

class EarlyStopping:
    """Early stops the training if validation loss doesn't improve after a given patience."""
    def __init__(self, patience=7, verbose=False, delta=0):
        """
        Args:
            patience (int): How long to wait after last time validation loss improved.
                            Default: 7
            verbose (bool): If True, prints a message for each validation loss improvement.
                            Default: False
            delta (float): Minimum change in the monitored quantity to qualify as an improvement.
                            Default: 0
        """
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.Inf
        self.delta = delta

    def __call__(self, val_loss, model):

        score = -val_loss

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score - self.delta:
            self.counter += 1
            print(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        '''Saves model when validation loss decrease.'''
        if self.verbose:
            print(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        torch.save(model.state_dict(), 'checkpoint.pt')
        self.val_loss_min = val_loss

# %%
# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Hyper-parameters
sequence_length = 0  # this parameter will be renewed in 'dataloader' function
input_size = 36  # including 6 channels of 6 IMU sensors, totally 36 channels
hidden_size = 256  # parameters for LSTM (Long Short Term Memory)
num_layers = 2  # the depth of Deep-RNNs
num_classes = 4 # number of classes
batch_size = 48 # training batch size
num_epochs = 60 # epoch number
lr = 5e-4 # learning rate
patience = 20 # patience for early stopping

# Test parameters
RANDOM_SEED_NUM = 0 # random seed
TEST_NUM = 5 # get best model from N trials by validation dataset
LABELS = ['right_standing', 'wrong_standing', 'right_turning', 'wrong_turning'] # action labels
DATASET_NAME = 'dataset.pkl' # the file name of dataset


def data_load():

    dataset_name0 = 'lin'
    dataset_name1 = 'zhong'
    actions = LABELS
    pkl_file = open(DATASET_NAME, 'rb')
    dataset = pickle.load(pkl_file)
    pkl_file.close()
    dataset0 = dataset[dataset_name0]
    dataset1 = dataset[dataset_name1]

    # get longest length among different actions
    max_t = max(dataset0['length_range'][1], dataset1['length_range'][1])
    global sequence_length
    sequence_length = max_t  # the longest length of sample

    # divide the dataset into train set, dev set and test set
    x_train, y_train, x_dev, y_dev, x_test, y_test = [], [], [], [], [], []
    for label, action in enumerate(actions):

        # lin
        labels = [label] * len(dataset0[action])
        temp_train_x, temp_test_x, temp_train_y, temp_test_y = \
            train_test_split(dataset0[action], labels, test_size=0.4, random_state=RANDOM_SEED_NUM)
        x_train += temp_train_x
        y_train += temp_train_y
        temp_train_x, temp_test_x, temp_train_y, temp_test_y = \
            train_test_split(temp_test_x, temp_test_y, test_size=0.5, random_state=RANDOM_SEED_NUM)
        x_dev += temp_train_x
        y_dev += temp_train_y
        x_test += temp_test_x
        y_test +=temp_test_y

        # zhong
        labels = [label] * len(dataset1[action])
        temp_train_x, temp_test_x, temp_train_y, temp_test_y = \
            train_test_split(dataset1[action], labels, test_size=0.4, random_state=RANDOM_SEED_NUM)
        x_train += temp_train_x
        y_train += temp_train_y
        temp_train_x, temp_test_x, temp_train_y, temp_test_y = \
            train_test_split(temp_test_x, temp_test_y, test_size=0.5, random_state=RANDOM_SEED_NUM)
        x_dev += temp_train_x
        y_dev += temp_train_y
        x_test += temp_test_x
        y_test += temp_test_y

    # data augmentation
    x_train, y_train = crop(x_train, y_train)

    # pad the data samples
    for i in range(len(x_train)):
        x_train[i] = \
            np.pad(x_train[i][:, 1:], ((0, max_t - x_train[i].shape[0]), (0, 0)), 'constant', constant_values=0)
    for i in range(len(x_dev)):
        x_dev[i] = \
            np.pad(x_dev[i][:, 1:], ((0, max_t - x_dev[i].shape[0]), (0, 0)), 'constant', constant_values=0)
    for i in range(len(x_test)):
        x_test[i] = \
            np.pad(x_test[i][:, 1:], ((0, max_t - x_test[i].shape[0]), (0, 0)), 'constant', constant_values=0)

    # shuffle
    x_train, y_train = shuffle(x_train, y_train, random_state=RANDOM_SEED_NUM+1)
    x_dev, y_dev = shuffle(x_dev, y_dev, random_state=RANDOM_SEED_NUM+2)
    x_test, y_test = shuffle(x_test, y_test, random_state=RANDOM_SEED_NUM+3)

    # change dataset's data format
    x_train, y_train = \
        torch.from_numpy(np.array(x_train)).type(torch.FloatTensor),\
        torch.from_numpy(np.array(y_train)).type(torch.LongTensor)
    x_dev, y_dev = \
        torch.from_numpy(np.array(x_dev)).type(torch.FloatTensor),\
        torch.from_numpy(np.array(y_dev)).type(torch.LongTensor)
    x_test, y_test = \
        torch.from_numpy(np.array(x_test)).type(torch.FloatTensor),\
        torch.from_numpy(np.array(y_test)).type(torch.LongTensor)

    return x_train, y_train, x_dev, y_dev, x_test, y_test


def training_model(num):
    # torch.manual_seed(RANDOM_SEED_NUM)
    global lr
    global patience
    # Load the dataset
    X_training, Y_training, X_valid, Y_valid, X_test, Y_test = data_load()
    # Record losses, accuracies and labels for drawing analysis figures
    train_losses = []
    valid_losses = []
    avg_train_losses = []
    avg_valid_losses = []
    # Early stopping mechanism
    early_stopping = EarlyStopping(patience=patience, verbose=False)
        
    # Create the model
    model = AttenBiRNN(input_size, hidden_size, num_layers, num_classes).to(device)
    # Multiple GPU setting
    if torch.cuda.device_count()>1:
        model = nn.DataParallel(model)
    # Loss and optimizer
    criterion = nn.CrossEntropyLoss() # Cross Entropy Loss funtion
    optimizer = torch.optim.Adam(model.parameters(), lr=lr) # Adam optimzer

    # Create Pytorch's dataloader for training, valid and test dataset
    train_dataset = TensorDataset(X_training, Y_training)
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    valid_dataset = TensorDataset(X_valid, Y_valid)
    valid_loader = DataLoader(valid_dataset)
    test_dataset = TensorDataset(X_test, Y_test)
    test_loader = DataLoader(test_dataset)

    # Start training the model
    for epoch in range(num_epochs):
        # Adjust learning rate according to epoch
        if epoch >= 15:
            lr = 1e-4
        if epoch >= 30:
            lr = 5e-5
        if epoch >= 45:
            lr = 1e-5
        adjust_learning_rate(optimizer, lr)
        
        '''Training'''
        model.train()  # prep model for tarining
        for batch, (inputs, labels) in enumerate(train_loader):
            inputs = inputs.reshape(-1, sequence_length, input_size).to(device)
            labels = labels.reshape(-1).to(device)
            # Forward pass
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            # Backward and optimize
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            # Record loss
            train_losses.append(loss.item())
        
        '''Validation'''
        model.eval() # prep model for validation
        for (inputs, labels) in valid_loader:
            inputs = inputs.reshape(-1, sequence_length, input_size).to(device)
            labels = labels.reshape(-1).to(device)
            # Forward pass
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            # record validation loss
            valid_losses.append(loss.item())
        
        # Calculate average loss over an epoch
        train_loss = np.average(train_losses)
        valid_loss = np.average(valid_losses)
        avg_train_losses.append(train_loss)
        avg_valid_losses.append(valid_loss)
        # Clear lists to track losses for next epoch
        train_losses = []
        valid_losses = []
        
        # Print information
        print('Trial [{}], Epoch [{}/{}], train loss: {:.5f}, valid loss: {:.5f}'
              .format(num+1, epoch + 1, num_epochs, train_loss, valid_loss))       
        # Early stop judgment
        early_stopping(valid_loss, model)
        if early_stopping.early_stop:
            print("Early stopping")
            break
            
    # Save the graph of variance and bias analysis
    save_name = 'trials' + str(num+1) + '_loss' + '.png'
    variance_and_bias_analysis(avg_train_losses, avg_valid_losses, save_name)
    # Load the last checkpoint with the best model
    model.load_state_dict(torch.load('checkpoint.pt'))

    return avg_valid_losses[-1], model, test_loader


def test_model(num, model, test_loader):
    # Test the model on test set
    model.eval()
    y_true = []
    y_pred = []
    correct = 0
    total = 0
    for (inputs, labels) in test_loader:
        inputs = inputs.reshape(-1, sequence_length, input_size).to(device)
        labels = labels.reshape(-1).to(device)
        outputs = model(inputs)
        _, predicted = torch.max(outputs.data, 1)
        # total += labels.size(0)
        # correct += (predicted == labels).sum().item()
        y_true.append(labels.item())
        y_pred.append(predicted.item())
    
    # accuracy = (correct/total)*100
    accuracy = accuracy_score(y_true, y_pred)
    recall = recall_score(y_true, y_pred, average='weighted')
    precision = precision_score(y_true, y_pred, average='weighted')
    f1 = f1_score(y_true, y_pred, average='weighted')
    
    print('Accuracy: {:.4f}%, Recall: {:.4f}%, Precision: {:.4f}%, F1: {:.4f}%'.format(accuracy*100, recall*100, precision*100, f1*100))
    save_name = 'trial'+str(num+1)+'_confusion_matrix' + '.png'
    labels_name = ['RS', 'WS', 'RT', 'WT']
    plot_confusion_matrix(y_true, y_pred, labels_name, save_name)
    
    return accuracy, recall, precision, f1


def main(num):
    accuracy_list, recall_list, precision_list, f1_list = [], [], [], []
    models = []
    for i in range(num):
        loss, model, test_loader = training_model(i)
        models.append(model)
        accuracy, recall, precision, f1 = test_model(i, model, test_loader)
        accuracy_list.append(accuracy)
        recall_list.append(recall)
        precision_list.append(precision)
        f1_list.append(f1)
    print('{} times average accuracy: {:.4f}%, recall: {:.4f}%, precision:{:.4f}%, f1: {:.4f}%.'
          .format(num, np.mean(accuracy_list), np.mean(recall_list), np.mean(precision_list), np.mean(f1_list)))
    index = f1_list.index(max(f1_list))
    best_model = models[index]
    # Save the modal checkpoint
    torch.save(best_model.state_dict(), 'DeepNAR_model.ckpt')

# %%
start = datetime.datetime.now()
main(num=TEST_NUM)
end = datetime.datetime.now()
print('Cost time: ', end-start)
# Out:
# /home/zhong/anaconda3/envs/DeepNAR/lib/python3.7/site-packages/torch/nn/modules/rnn.py:522: RuntimeWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
#   self.dropout, self.training, self.bidirectional, self.batch_first)
# Trial [1], Epoch [1/60], train loss: 1.29058, valid loss: 1.14437
# Trial [1], Epoch [2/60], train loss: 1.00103, valid loss: 0.80617
# Trial [1], Epoch [3/60], train loss: 0.68183, valid loss: 0.53325
# Trial [1], Epoch [4/60], train loss: 0.42505, valid loss: 0.34267
# Trial [1], Epoch [5/60], train loss: 0.25001, valid loss: 0.24657
# Trial [1], Epoch [6/60], train loss: 0.14277, valid loss: 0.18679
# Trial [1], Epoch [7/60], train loss: 0.06932, valid loss: 0.13906
# Trial [1], Epoch [8/60], train loss: 0.02879, valid loss: 0.12223
# Trial [1], Epoch [9/60], train loss: 0.01186, valid loss: 0.07436
# Trial [1], Epoch [10/60], train loss: 0.00615, valid loss: 0.03859
# Trial [1], Epoch [11/60], train loss: 0.00378, valid loss: 0.02890
# Trial [1], Epoch [12/60], train loss: 0.00265, valid loss: 0.02736
# Trial [1], Epoch [13/60], train loss: 0.00202, valid loss: 0.02930
# EarlyStopping counter: 1 out of 20
# Trial [1], Epoch [14/60], train loss: 0.00167, valid loss: 0.03004
# EarlyStopping counter: 2 out of 20
# Trial [1], Epoch [15/60], train loss: 0.00142, valid loss: 0.03072
# EarlyStopping counter: 3 out of 20
# Trial [1], Epoch [16/60], train loss: 0.00130, valid loss: 0.02979
# EarlyStopping counter: 4 out of 20
# Trial [1], Epoch [17/60], train loss: 0.00127, valid loss: 0.02890
# EarlyStopping counter: 5 out of 20
# Trial [1], Epoch [18/60], train loss: 0.00124, valid loss: 0.02776
# EarlyStopping counter: 6 out of 20
# Trial [1], Epoch [19/60], train loss: 0.00121, valid loss: 0.02712
# Trial [1], Epoch [20/60], train loss: 0.00119, valid loss: 0.02661
# Trial [1], Epoch [21/60], train loss: 0.00116, valid loss: 0.02627
# Trial [1], Epoch [22/60], train loss: 0.00114, valid loss: 0.02600
# Trial [1], Epoch [23/60], train loss: 0.00111, valid loss: 0.02552
# Trial [1], Epoch [24/60], train loss: 0.00109, valid loss: 0.02550
# Trial [1], Epoch [25/60], train loss: 0.00107, valid loss: 0.02574
# EarlyStopping counter: 1 out of 20
# Trial [1], Epoch [26/60], train loss: 0.00105, valid loss: 0.02592
# EarlyStopping counter: 2 out of 20
# Trial [1], Epoch [27/60], train loss: 0.00102, valid loss: 0.02574
# EarlyStopping counter: 3 out of 20
# Trial [1], Epoch [28/60], train loss: 0.00100, valid loss: 0.02546
# Trial [1], Epoch [29/60], train loss: 0.00098, valid loss: 0.02520
# Trial [1], Epoch [30/60], train loss: 0.00096, valid loss: 0.02470
# Trial [1], Epoch [31/60], train loss: 0.00094, valid loss: 0.02454
# Trial [1], Epoch [32/60], train loss: 0.00093, valid loss: 0.02456
# EarlyStopping counter: 1 out of 20
# Trial [1], Epoch [33/60], train loss: 0.00092, valid loss: 0.02477
# EarlyStopping counter: 2 out of 20
# Trial [1], Epoch [34/60], train loss: 0.00091, valid loss: 0.02491
# EarlyStopping counter: 3 out of 20
# Trial [1], Epoch [35/60], train loss: 0.00090, valid loss: 0.02495
# EarlyStopping counter: 4 out of 20
# Trial [1], Epoch [36/60], train loss: 0.00089, valid loss: 0.02482
# EarlyStopping counter: 5 out of 20
# Trial [1], Epoch [37/60], train loss: 0.00088, valid loss: 0.02474
# EarlyStopping counter: 6 out of 20
# Trial [1], Epoch [38/60], train loss: 0.00087, valid loss: 0.02468
# EarlyStopping counter: 7 out of 20
# Trial [1], Epoch [39/60], train loss: 0.00086, valid loss: 0.02466
# EarlyStopping counter: 8 out of 20
# Trial [1], Epoch [40/60], train loss: 0.00085, valid loss: 0.02456
# EarlyStopping counter: 9 out of 20
# Trial [1], Epoch [41/60], train loss: 0.00084, valid loss: 0.02452
# Trial [1], Epoch [42/60], train loss: 0.00083, valid loss: 0.02432
# Trial [1], Epoch [43/60], train loss: 0.00082, valid loss: 0.02416
# Trial [1], Epoch [44/60], train loss: 0.00081, valid loss: 0.02396
# Trial [1], Epoch [45/60], train loss: 0.00080, valid loss: 0.02399
# EarlyStopping counter: 1 out of 20
# Trial [1], Epoch [46/60], train loss: 0.00079, valid loss: 0.02393
# Trial [1], Epoch [47/60], train loss: 0.00079, valid loss: 0.02391
# Trial [1], Epoch [48/60], train loss: 0.00079, valid loss: 0.02387
# Trial [1], Epoch [49/60], train loss: 0.00078, valid loss: 0.02385
# Trial [1], Epoch [50/60], train loss: 0.00078, valid loss: 0.02382
# Trial [1], Epoch [51/60], train loss: 0.00077, valid loss: 0.02378
# Trial [1], Epoch [52/60], train loss: 0.00077, valid loss: 0.02371
# Trial [1], Epoch [53/60], train loss: 0.00076, valid loss: 0.02362
# Trial [1], Epoch [54/60], train loss: 0.00075, valid loss: 0.02353
# Trial [1], Epoch [55/60], train loss: 0.00074, valid loss: 0.02349
# Trial [1], Epoch [56/60], train loss: 0.00073, valid loss: 0.02346
# Trial [1], Epoch [57/60], train loss: 0.00072, valid loss: 0.02339
# Trial [1], Epoch [58/60], train loss: 0.00070, valid loss: 0.02334
# Trial [1], Epoch [59/60], train loss: 0.00068, valid loss: 0.02335
# EarlyStopping counter: 1 out of 20
# Trial [1], Epoch [60/60], train loss: 0.00065, valid loss: 0.02331
# Accuracy: 93.7500%, Recall: 93.7500%, Precision: 93.7500%, F1: 93.7500%
# Trial [2], Epoch [1/60], train loss: 1.38302, valid loss: 1.38284
# Trial [2], Epoch [2/60], train loss: 1.37903, valid loss: 1.37879
# Trial [2], Epoch [3/60], train loss: 1.37482, valid loss: 1.37427
# Trial [2], Epoch [4/60], train loss: 1.37009, valid loss: 1.36941
# Trial [2], Epoch [5/60], train loss: 1.36489, valid loss: 1.36424
# Trial [2], Epoch [6/60], train loss: 1.35941, valid loss: 1.35865
# Trial [2], Epoch [7/60], train loss: 1.35357, valid loss: 1.35265
# Trial [2], Epoch [8/60], train loss: 1.34767, valid loss: 1.34624
# Trial [2], Epoch [9/60], train loss: 1.34132, valid loss: 1.33963
# Trial [2], Epoch [10/60], train loss: 1.33476, valid loss: 1.33287
# Trial [2], Epoch [11/60], train loss: 1.32808, valid loss: 1.32589
# Trial [2], Epoch [12/60], train loss: 1.32114, valid loss: 1.31877
# Trial [2], Epoch [13/60], train loss: 1.31389, valid loss: 1.31154
# Trial [2], Epoch [14/60], train loss: 1.30649, valid loss: 1.30408
# Trial [2], Epoch [15/60], train loss: 1.29874, valid loss: 1.29636
# Trial [2], Epoch [16/60], train loss: 1.25915, valid loss: 1.20660
# Trial [2], Epoch [17/60], train loss: 1.15668, valid loss: 1.08704
# Trial [2], Epoch [18/60], train loss: 1.02786, valid loss: 0.95363
# Trial [2], Epoch [19/60], train loss: 0.89911, valid loss: 0.83172
# Trial [2], Epoch [20/60], train loss: 0.78350, valid loss: 0.73810
# Trial [2], Epoch [21/60], train loss: 0.69084, valid loss: 0.65502
# Trial [2], Epoch [22/60], train loss: 0.60676, valid loss: 0.57392
# Trial [2], Epoch [23/60], train loss: 0.51658, valid loss: 0.48646
# Trial [2], Epoch [24/60], train loss: 0.42021, valid loss: 0.38741
# Trial [2], Epoch [25/60], train loss: 0.30535, valid loss: 0.30450
# Trial [2], Epoch [26/60], train loss: 0.19729, valid loss: 0.22299
# Trial [2], Epoch [27/60], train loss: 0.11929, valid loss: 0.18408
# Trial [2], Epoch [28/60], train loss: 0.07297, valid loss: 0.20286
# EarlyStopping counter: 1 out of 20
# Trial [2], Epoch [29/60], train loss: 0.04721, valid loss: 0.18879
# EarlyStopping counter: 2 out of 20
# Trial [2], Epoch [30/60], train loss: 0.03290, valid loss: 0.21767
# EarlyStopping counter: 3 out of 20
# Trial [2], Epoch [31/60], train loss: 0.02563, valid loss: 0.22364
# EarlyStopping counter: 4 out of 20
# Trial [2], Epoch [32/60], train loss: 0.02242, valid loss: 0.22182
# EarlyStopping counter: 5 out of 20
# Trial [2], Epoch [33/60], train loss: 0.01988, valid loss: 0.22355
# EarlyStopping counter: 6 out of 20
# Trial [2], Epoch [34/60], train loss: 0.01794, valid loss: 0.22546
# EarlyStopping counter: 7 out of 20
# Trial [2], Epoch [35/60], train loss: 0.01632, valid loss: 0.23111
# EarlyStopping counter: 8 out of 20
# Trial [2], Epoch [36/60], train loss: 0.01495, valid loss: 0.23485
# EarlyStopping counter: 9 out of 20
# Trial [2], Epoch [37/60], train loss: 0.01378, valid loss: 0.23640
# EarlyStopping counter: 10 out of 20
# Trial [2], Epoch [38/60], train loss: 0.01278, valid loss: 0.24249
# EarlyStopping counter: 11 out of 20
# Trial [2], Epoch [39/60], train loss: 0.01186, valid loss: 0.24430
# EarlyStopping counter: 12 out of 20
# Trial [2], Epoch [40/60], train loss: 0.01106, valid loss: 0.24563
# EarlyStopping counter: 13 out of 20
# Trial [2], Epoch [41/60], train loss: 0.01036, valid loss: 0.24865
# EarlyStopping counter: 14 out of 20
# Trial [2], Epoch [42/60], train loss: 0.00970, valid loss: 0.25234
# EarlyStopping counter: 15 out of 20
# Trial [2], Epoch [43/60], train loss: 0.00911, valid loss: 0.25618
# EarlyStopping counter: 16 out of 20
# Trial [2], Epoch [44/60], train loss: 0.00857, valid loss: 0.25915
# EarlyStopping counter: 17 out of 20
# Trial [2], Epoch [45/60], train loss: 0.00806, valid loss: 0.27050
# EarlyStopping counter: 18 out of 20
# Trial [2], Epoch [46/60], train loss: 0.00774, valid loss: 0.27459
# EarlyStopping counter: 19 out of 20
# Trial [2], Epoch [47/60], train loss: 0.00765, valid loss: 0.27695
# EarlyStopping counter: 20 out of 20
# Early stopping
# Accuracy: 96.8750%, Recall: 96.8750%, Precision: 97.2222%, F1: 96.8627%
# Trial [3], Epoch [1/60], train loss: 1.38502, valid loss: 1.38639
# Trial [3], Epoch [2/60], train loss: 1.38230, valid loss: 1.38441
# Trial [3], Epoch [3/60], train loss: 1.37964, valid loss: 1.38228
# Trial [3], Epoch [4/60], train loss: 1.37673, valid loss: 1.37999
# Trial [3], Epoch [5/60], train loss: 1.37369, valid loss: 1.37748
# Trial [3], Epoch [6/60], train loss: 1.37026, valid loss: 1.37476
# Trial [3], Epoch [7/60], train loss: 1.36661, valid loss: 1.37179
# Trial [3], Epoch [8/60], train loss: 1.36269, valid loss: 1.36856
# Trial [3], Epoch [9/60], train loss: 1.35856, valid loss: 1.36503
# Trial [3], Epoch [10/60], train loss: 1.35419, valid loss: 1.36122
# Trial [3], Epoch [11/60], train loss: 1.34954, valid loss: 1.35724
# Trial [3], Epoch [12/60], train loss: 1.34477, valid loss: 1.35303
# Trial [3], Epoch [13/60], train loss: 1.33958, valid loss: 1.34829
# Trial [3], Epoch [14/60], train loss: 1.33343, valid loss: 1.34081
# Trial [3], Epoch [15/60], train loss: 1.32521, valid loss: 1.33022
# Trial [3], Epoch [16/60], train loss: 1.29050, valid loss: 1.25168
# Trial [3], Epoch [17/60], train loss: 1.19918, valid loss: 1.13809
# Trial [3], Epoch [18/60], train loss: 1.07666, valid loss: 1.00397
# Trial [3], Epoch [19/60], train loss: 0.93874, valid loss: 0.87129
# Trial [3], Epoch [20/60], train loss: 0.80337, valid loss: 0.74077
# Trial [3], Epoch [21/60], train loss: 0.67474, valid loss: 0.62595
# Trial [3], Epoch [22/60], train loss: 0.55276, valid loss: 0.50814
# Trial [3], Epoch [23/60], train loss: 0.42858, valid loss: 0.40276
# Trial [3], Epoch [24/60], train loss: 0.31229, valid loss: 0.31201
# Trial [3], Epoch [25/60], train loss: 0.21373, valid loss: 0.23945
# Trial [3], Epoch [26/60], train loss: 0.13698, valid loss: 0.20716
# Trial [3], Epoch [27/60], train loss: 0.08267, valid loss: 0.14365
# Trial [3], Epoch [28/60], train loss: 0.05383, valid loss: 0.24450
# EarlyStopping counter: 1 out of 20
# Trial [3], Epoch [29/60], train loss: 0.03652, valid loss: 0.27147
# EarlyStopping counter: 2 out of 20
# Trial [3], Epoch [30/60], train loss: 0.02666, valid loss: 0.21984
# EarlyStopping counter: 3 out of 20
# Trial [3], Epoch [31/60], train loss: 0.02158, valid loss: 0.21522
# EarlyStopping counter: 4 out of 20
# Trial [3], Epoch [32/60], train loss: 0.01945, valid loss: 0.21375
# EarlyStopping counter: 5 out of 20
# Trial [3], Epoch [33/60], train loss: 0.01778, valid loss: 0.21507
# EarlyStopping counter: 6 out of 20
# Trial [3], Epoch [34/60], train loss: 0.01633, valid loss: 0.22003
# EarlyStopping counter: 7 out of 20
# Trial [3], Epoch [35/60], train loss: 0.01511, valid loss: 0.22532
# EarlyStopping counter: 8 out of 20
# Trial [3], Epoch [36/60], train loss: 0.01406, valid loss: 0.22862
# EarlyStopping counter: 9 out of 20
# Trial [3], Epoch [37/60], train loss: 0.01310, valid loss: 0.23305
# EarlyStopping counter: 10 out of 20
# Trial [3], Epoch [38/60], train loss: 0.01224, valid loss: 0.24051
# EarlyStopping counter: 11 out of 20
# Trial [3], Epoch [39/60], train loss: 0.01146, valid loss: 0.24643
# EarlyStopping counter: 12 out of 20
# Trial [3], Epoch [40/60], train loss: 0.01077, valid loss: 0.25000
# EarlyStopping counter: 13 out of 20
# Trial [3], Epoch [41/60], train loss: 0.01015, valid loss: 0.25141
# EarlyStopping counter: 14 out of 20
# Trial [3], Epoch [42/60], train loss: 0.00959, valid loss: 0.25016
# EarlyStopping counter: 15 out of 20
# Trial [3], Epoch [43/60], train loss: 0.00907, valid loss: 0.25054
# EarlyStopping counter: 16 out of 20
# Trial [3], Epoch [44/60], train loss: 0.00858, valid loss: 0.25385
# EarlyStopping counter: 17 out of 20
# Trial [3], Epoch [45/60], train loss: 0.00815, valid loss: 0.25923
# EarlyStopping counter: 18 out of 20
# Trial [3], Epoch [46/60], train loss: 0.00787, valid loss: 0.25970
# EarlyStopping counter: 19 out of 20
# Trial [3], Epoch [47/60], train loss: 0.00779, valid loss: 0.25977
# EarlyStopping counter: 20 out of 20
# Early stopping
# Accuracy: 93.7500%, Recall: 93.7500%, Precision: 94.4444%, F1: 93.7255%
# Trial [4], Epoch [1/60], train loss: 1.37818, valid loss: 1.37779
# Trial [4], Epoch [2/60], train loss: 1.37242, valid loss: 1.37185
# Trial [4], Epoch [3/60], train loss: 1.36628, valid loss: 1.36613
# Trial [4], Epoch [4/60], train loss: 1.36035, valid loss: 1.35971
# Trial [4], Epoch [5/60], train loss: 1.35387, valid loss: 1.35292
# Trial [4], Epoch [6/60], train loss: 1.34703, valid loss: 1.34572
# Trial [4], Epoch [7/60], train loss: 1.33983, valid loss: 1.33828
# Trial [4], Epoch [8/60], train loss: 1.33215, valid loss: 1.33053
# Trial [4], Epoch [9/60], train loss: 1.32429, valid loss: 1.32237
# Trial [4], Epoch [10/60], train loss: 1.31631, valid loss: 1.31366
# Trial [4], Epoch [11/60], train loss: 1.30775, valid loss: 1.30479
# Trial [4], Epoch [12/60], train loss: 1.29924, valid loss: 1.29618
# Trial [4], Epoch [13/60], train loss: 1.29074, valid loss: 1.28776
# Trial [4], Epoch [14/60], train loss: 1.28217, valid loss: 1.27923
# Trial [4], Epoch [15/60], train loss: 1.27348, valid loss: 1.27054
# Trial [4], Epoch [16/60], train loss: 1.23036, valid loss: 1.17728
# Trial [4], Epoch [17/60], train loss: 1.13230, valid loss: 1.06783
# Trial [4], Epoch [18/60], train loss: 1.01554, valid loss: 0.94049
# Trial [4], Epoch [19/60], train loss: 0.88610, valid loss: 0.81009
# Trial [4], Epoch [20/60], train loss: 0.75854, valid loss: 0.68431
# Trial [4], Epoch [21/60], train loss: 0.63094, valid loss: 0.56320
# Trial [4], Epoch [22/60], train loss: 0.51569, valid loss: 0.46061
# Trial [4], Epoch [23/60], train loss: 0.42781, valid loss: 0.39560
# Trial [4], Epoch [24/60], train loss: 0.36959, valid loss: 0.35357
# Trial [4], Epoch [25/60], train loss: 0.33063, valid loss: 0.32310
# Trial [4], Epoch [26/60], train loss: 0.30330, valid loss: 0.30342
# Trial [4], Epoch [27/60], train loss: 0.27982, valid loss: 0.28479
# Trial [4], Epoch [28/60], train loss: 0.26090, valid loss: 0.28250
# Trial [4], Epoch [29/60], train loss: 0.24191, valid loss: 0.26137
# Trial [4], Epoch [30/60], train loss: 0.21868, valid loss: 0.23130
# Trial [4], Epoch [31/60], train loss: 0.19612, valid loss: 0.22067
# Trial [4], Epoch [32/60], train loss: 0.18353, valid loss: 0.21185
# Trial [4], Epoch [33/60], train loss: 0.17016, valid loss: 0.20447
# Trial [4], Epoch [34/60], train loss: 0.15719, valid loss: 0.19325
# Trial [4], Epoch [35/60], train loss: 0.14428, valid loss: 0.18268
# Trial [4], Epoch [36/60], train loss: 0.13170, valid loss: 0.17386
# Trial [4], Epoch [37/60], train loss: 0.11981, valid loss: 0.16522
# Trial [4], Epoch [38/60], train loss: 0.10178, valid loss: 0.14123
# Trial [4], Epoch [39/60], train loss: 0.07840, valid loss: 0.14098
# Trial [4], Epoch [40/60], train loss: 0.06220, valid loss: 0.09526
# Trial [4], Epoch [41/60], train loss: 0.04823, valid loss: 0.08097
# Trial [4], Epoch [42/60], train loss: 0.03871, valid loss: 0.07499
# Trial [4], Epoch [43/60], train loss: 0.03167, valid loss: 0.06450
# Trial [4], Epoch [44/60], train loss: 0.02620, valid loss: 0.05337
# Trial [4], Epoch [45/60], train loss: 0.02186, valid loss: 0.05074
# Trial [4], Epoch [46/60], train loss: 0.01967, valid loss: 0.05061
# Trial [4], Epoch [47/60], train loss: 0.01913, valid loss: 0.05033
# Trial [4], Epoch [48/60], train loss: 0.01863, valid loss: 0.04987
# Trial [4], Epoch [49/60], train loss: 0.01819, valid loss: 0.04965
# Trial [4], Epoch [50/60], train loss: 0.01775, valid loss: 0.04891
# Trial [4], Epoch [51/60], train loss: 0.01735, valid loss: 0.04840
# Trial [4], Epoch [52/60], train loss: 0.01696, valid loss: 0.04785
# Trial [4], Epoch [53/60], train loss: 0.01659, valid loss: 0.04751
# Trial [4], Epoch [54/60], train loss: 0.01622, valid loss: 0.04683
# Trial [4], Epoch [55/60], train loss: 0.01588, valid loss: 0.04612
# Trial [4], Epoch [56/60], train loss: 0.01554, valid loss: 0.04533
# Trial [4], Epoch [57/60], train loss: 0.01522, valid loss: 0.04498
# Trial [4], Epoch [58/60], train loss: 0.01490, valid loss: 0.04436
# Trial [4], Epoch [59/60], train loss: 0.01460, valid loss: 0.04387
# Trial [4], Epoch [60/60], train loss: 0.01431, valid loss: 0.04359
# Accuracy: 93.7500%, Recall: 93.7500%, Precision: 94.4444%, F1: 93.7255%
# Trial [5], Epoch [1/60], train loss: 1.38523, valid loss: 1.38324
# Trial [5], Epoch [2/60], train loss: 1.38150, valid loss: 1.37993
# Trial [5], Epoch [3/60], train loss: 1.37792, valid loss: 1.37647
# Trial [5], Epoch [4/60], train loss: 1.37393, valid loss: 1.37273
# Trial [5], Epoch [5/60], train loss: 1.36978, valid loss: 1.36857
# Trial [5], Epoch [6/60], train loss: 1.36523, valid loss: 1.36395
# Trial [5], Epoch [7/60], train loss: 1.36030, valid loss: 1.35878
# Trial [5], Epoch [8/60], train loss: 1.35475, valid loss: 1.35312
# Trial [5], Epoch [9/60], train loss: 1.34861, valid loss: 1.34694
# Trial [5], Epoch [10/60], train loss: 1.34201, valid loss: 1.34027
# Trial [5], Epoch [11/60], train loss: 1.33486, valid loss: 1.33312
# Trial [5], Epoch [12/60], train loss: 1.32700, valid loss: 1.32528
# Trial [5], Epoch [13/60], train loss: 1.31893, valid loss: 1.31713
# Trial [5], Epoch [14/60], train loss: 1.31064, valid loss: 1.30829
# Trial [5], Epoch [15/60], train loss: 1.30166, valid loss: 1.29884
# Trial [5], Epoch [16/60], train loss: 1.25656, valid loss: 1.19332
# Trial [5], Epoch [17/60], train loss: 1.14257, valid loss: 1.05837
# Trial [5], Epoch [18/60], train loss: 0.99446, valid loss: 0.89308
# Trial [5], Epoch [19/60], train loss: 0.84294, valid loss: 0.78974
# Trial [5], Epoch [20/60], train loss: 0.74300, valid loss: 0.66972
# Trial [5], Epoch [21/60], train loss: 0.57305, valid loss: 0.57882
# Trial [5], Epoch [22/60], train loss: 0.44289, valid loss: 0.40435
# Trial [5], Epoch [23/60], train loss: 0.33131, valid loss: 0.32423
# Trial [5], Epoch [24/60], train loss: 0.22528, valid loss: 0.18527
# Trial [5], Epoch [25/60], train loss: 0.15432, valid loss: 0.14209
# Trial [5], Epoch [26/60], train loss: 0.10134, valid loss: 0.12771
# Trial [5], Epoch [27/60], train loss: 0.07165, valid loss: 0.10529
# Trial [5], Epoch [28/60], train loss: 0.05256, valid loss: 0.12700
# EarlyStopping counter: 1 out of 20
# Trial [5], Epoch [29/60], train loss: 0.04028, valid loss: 0.14077
# EarlyStopping counter: 2 out of 20
# Trial [5], Epoch [30/60], train loss: 0.03199, valid loss: 0.14013
# EarlyStopping counter: 3 out of 20
# Trial [5], Epoch [31/60], train loss: 0.02729, valid loss: 0.13474
# EarlyStopping counter: 4 out of 20
# Trial [5], Epoch [32/60], train loss: 0.02503, valid loss: 0.12650
# EarlyStopping counter: 5 out of 20
# Trial [5], Epoch [33/60], train loss: 0.02315, valid loss: 0.11826
# EarlyStopping counter: 6 out of 20
# Trial [5], Epoch [34/60], train loss: 0.02151, valid loss: 0.11154
# EarlyStopping counter: 7 out of 20
# Trial [5], Epoch [35/60], train loss: 0.02009, valid loss: 0.10583
# EarlyStopping counter: 8 out of 20
# Trial [5], Epoch [36/60], train loss: 0.01881, valid loss: 0.10069
# Trial [5], Epoch [37/60], train loss: 0.01767, valid loss: 0.09678
# Trial [5], Epoch [38/60], train loss: 0.01664, valid loss: 0.09372
# Trial [5], Epoch [39/60], train loss: 0.01570, valid loss: 0.09126
# Trial [5], Epoch [40/60], train loss: 0.01482, valid loss: 0.08933
# Trial [5], Epoch [41/60], train loss: 0.01403, valid loss: 0.08797
# Trial [5], Epoch [42/60], train loss: 0.01331, valid loss: 0.08699
# Trial [5], Epoch [43/60], train loss: 0.01261, valid loss: 0.08671
# Trial [5], Epoch [44/60], train loss: 0.01199, valid loss: 0.08678
# EarlyStopping counter: 1 out of 20
# Trial [5], Epoch [45/60], train loss: 0.01141, valid loss: 0.08719
# EarlyStopping counter: 2 out of 20
# Trial [5], Epoch [46/60], train loss: 0.01105, valid loss: 0.08734
# EarlyStopping counter: 3 out of 20
# Trial [5], Epoch [47/60], train loss: 0.01094, valid loss: 0.08748
# EarlyStopping counter: 4 out of 20
# Trial [5], Epoch [48/60], train loss: 0.01084, valid loss: 0.08759
# EarlyStopping counter: 5 out of 20
# Trial [5], Epoch [49/60], train loss: 0.01074, valid loss: 0.08782
# EarlyStopping counter: 6 out of 20
# Trial [5], Epoch [50/60], train loss: 0.01064, valid loss: 0.08796
# EarlyStopping counter: 7 out of 20
# Trial [5], Epoch [51/60], train loss: 0.01054, valid loss: 0.08810
# EarlyStopping counter: 8 out of 20
# Trial [5], Epoch [52/60], train loss: 0.01044, valid loss: 0.08823
# EarlyStopping counter: 9 out of 20
# Trial [5], Epoch [53/60], train loss: 0.01035, valid loss: 0.08838
# EarlyStopping counter: 10 out of 20
# Trial [5], Epoch [54/60], train loss: 0.01025, valid loss: 0.08861
# EarlyStopping counter: 11 out of 20
# Trial [5], Epoch [55/60], train loss: 0.01015, valid loss: 0.08875
# EarlyStopping counter: 12 out of 20
# Trial [5], Epoch [56/60], train loss: 0.01006, valid loss: 0.08897
# EarlyStopping counter: 13 out of 20
# Trial [5], Epoch [57/60], train loss: 0.00996, valid loss: 0.08916
# EarlyStopping counter: 14 out of 20
# Trial [5], Epoch [58/60], train loss: 0.00987, valid loss: 0.08937
# EarlyStopping counter: 15 out of 20
# Trial [5], Epoch [59/60], train loss: 0.00978, valid loss: 0.08948
# EarlyStopping counter: 16 out of 20
# Trial [5], Epoch [60/60], train loss: 0.00968, valid loss: 0.08972
# EarlyStopping counter: 17 out of 20
# Accuracy: 96.8750%, Recall: 96.8750%, Precision: 97.2222%, F1: 96.8627%
# 5 times average accuracy: 0.9500%, recall: 0.9500%, precision:0.9542%, f1: 0.9499%.
# Cost time:  0:03:13.259705
