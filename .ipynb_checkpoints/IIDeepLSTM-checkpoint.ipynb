# %%
import pickle
import numpy as np
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from network import BiRNN, RNN
from visualization import variance_and_bias_analysis, plot_confusion_matrix, show, save, data_visual
from data_optimization import dimension_reduce, normalization, intra_iteration
from data_augmentation import crop
import datetime

# %%
# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Hyper-parameters
sequence_length = 0  # this parameter will be renewed in 'dataloader' function
input_size = 36  # including 6 channels of 6 IMU sensors, totally 36 channels
hidden_size = 256  # parameters for LSTM (Long Short Term Memory)
num_layers = 2  # the depth of Deep-RNNs
num_classes = 4
batch_size = 48
num_epochs = 60
learning_rate = 0.01

# Test parameters
RANDOM_SEED_NUM = 0
TRIALS_NUM = 5
LABELS = ['right_standing', 'wrong_standing', 'right_turning', 'wrong_turning']
DATASET_NAME = 'dataset.pkl'


def data_load():

    dataset_name0 = 'lin'
    dataset_name1 = 'zhong'
    actions = LABELS
    pkl_file = open(DATASET_NAME, 'rb')
    dataset = pickle.load(pkl_file)
    pkl_file.close()
    dataset0 = dataset[dataset_name0]
    dataset1 = dataset[dataset_name1]

    # get longest time length among different actions
    max_t = max(dataset0['length_range'][1], dataset1['length_range'][1])
    global sequence_length
    sequence_length = max_t  # the longest length of sample

    # divide the dataset into train set, dev set and test set
    x_train, y_train, x_dev, y_dev, x_test, y_test = [], [], [], [], [], []
    for label, action in enumerate(actions):

        # lin
        labels = [label] * len(dataset0[action])
        temp_train_x, temp_test_x, temp_train_y, temp_test_y = \
            train_test_split(dataset0[action], labels, test_size=0.4, random_state=RANDOM_SEED_NUM)
        x_train += temp_train_x
        y_train += temp_train_y
        temp_train_x, temp_test_x, temp_train_y, temp_test_y = \
            train_test_split(temp_test_x, temp_test_y, test_size=0.5, random_state=RANDOM_SEED_NUM)
        x_dev += temp_train_x
        y_dev += temp_train_y
        x_test += temp_test_x
        y_test +=temp_test_y

        # zhong
        labels = [label] * len(dataset1[action])
        temp_train_x, temp_test_x, temp_train_y, temp_test_y = \
            train_test_split(dataset1[action], labels, test_size=0.4, random_state=RANDOM_SEED_NUM)
        x_train += temp_train_x
        y_train += temp_train_y
        temp_train_x, temp_test_x, temp_train_y, temp_test_y = \
            train_test_split(temp_test_x, temp_test_y, test_size=0.5, random_state=RANDOM_SEED_NUM)
        x_dev += temp_train_x
        y_dev += temp_train_y
        x_test += temp_test_x
        y_test += temp_test_y

    # data augmentation
    x_train, y_train = crop(x_train, y_train)

    # pad the data samples
    for i in range(len(x_train)):
        x_train[i] = \
            np.pad(x_train[i][:, 1:], ((0, max_t - x_train[i].shape[0]), (0, 0)), 'constant', constant_values=0)
    for i in range(len(x_dev)):
        x_dev[i] = \
            np.pad(x_dev[i][:, 1:], ((0, max_t - x_dev[i].shape[0]), (0, 0)), 'constant', constant_values=0)
    for i in range(len(x_test)):
        x_test[i] = \
            np.pad(x_test[i][:, 1:], ((0, max_t - x_test[i].shape[0]), (0, 0)), 'constant', constant_values=0)
    
    # Intra-iteration
    x_train = intra_iteration(x_train)
    x_dev = intra_iteration(x_dev)
    x_test = intra_iteration(x_test)
    print(x_train[0].shape)
    
    # update longest time length among different actions
    sequence_length = x_train[0].shape[0]  # the longest length of sample
    
    # shuffle
    x_train, y_train = shuffle(x_train, y_train, random_state=RANDOM_SEED_NUM+1)
    x_dev, y_dev = shuffle(x_dev, y_dev, random_state=RANDOM_SEED_NUM+2)
    x_test, y_test = shuffle(x_test, y_test, random_state=RANDOM_SEED_NUM+3)

    # change dataset's data format
    x_train, y_train = \
        torch.from_numpy(np.array(x_train)).type(torch.FloatTensor),\
        torch.from_numpy(np.array(y_train)).type(torch.LongTensor)
    x_dev, y_dev = \
        torch.from_numpy(np.array(x_dev)).type(torch.FloatTensor),\
        torch.from_numpy(np.array(y_dev)).type(torch.LongTensor)
    x_test, y_test = \
        torch.from_numpy(np.array(x_test)).type(torch.FloatTensor),\
        torch.from_numpy(np.array(y_test)).type(torch.LongTensor)

    return x_train, y_train, x_dev, y_dev, x_test, y_test


def training_model(num):
    # torch.manual_seed(RANDOM_SEED_NUM)

    # Load the dataset
    X_training, Y_training, X_dev, Y_dev, X_test, Y_test = data_load()
    
    # Record losses, accuracies and labels for drawing analysis figures
    training_losses = []
    test_accuracies = []
    y_true = []
    y_pred = []

    # Create the model
    model = BiRNN(input_size, hidden_size, num_layers, num_classes).to(device)

    # Loss and optimizer
    criterion = nn.CrossEntropyLoss() # Cross Entropy Loss funtion
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate) # Adam optimzer

    # Create Pytorch's dataloader for training, valid and test dataset
    train_dataset = TensorDataset(X_training, Y_training)
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    dev_dataset = TensorDataset(X_dev, Y_dev)
    dev_loader = DataLoader(dev_dataset)
    test_dataset = TensorDataset(X_test, Y_test)
    test_loader = DataLoader(test_dataset)

    # Start training the model
    for epoch in range(num_epochs):
        for i, (inputs, labels) in enumerate(train_loader):
            inputs = inputs.reshape(-1, sequence_length, input_size).to(device)
            labels = labels.reshape(-1).to(device)
            # Forward pass
            outputs = model(inputs)
            training_loss = criterion(outputs, labels)
            # Backward and optimize
            optimizer.zero_grad()
            training_loss.backward()
            optimizer.step()
            
        # Print information, collect the training loss and valid accuracy for every 2 epoches
        if (epoch + 1) % 2 == 0:
            # Print information
            print('Test [{}], Epoch [{}/{}], Loss: {:.4f}'
                  .format(num+1, epoch + 1, num_epochs, training_loss.item()))
            # Get the value of loss
            training_losses.append(training_loss.item())
            # Test the model on valid dataset
            with torch.no_grad():
                y_true = []
                y_pred = []
                correct = 0
                total = 0
                for j, (inputs, labels) in enumerate(dev_loader):
                    inputs = inputs.reshape(-1, sequence_length, input_size).to(device)
                    labels = labels.reshape(-1).to(device)
                    outputs = model(inputs)
                    _, predicted = torch.max(outputs.data, 1)
                    total += labels.size(0)
                    correct += (predicted == labels).sum().item()
                    y_true.append(labels.item())
                    y_pred.append(predicted.item())
                test_accuracies.append(correct/total)

    # Print accuracy of the model
    accuracy = test_accuracies[-1]*100
    print('Dev accuracy of the No.{} model on dev action samples: {} %'.format(num+1, accuracy))

    # Show or save the graph of variance and bias analysis, and confusion matrix graph
    variance_and_bias_analysis([training_losses], [test_accuracies])
    save('trials' + str(num+1) + '_loss_accuracy' + '.png')
    plot_confusion_matrix([y_true], [y_pred], LABELS)
    save('trials_' + str(num+1) + '_confusion_matrix' + '.png')

    return accuracy, model, test_loader


def test_model(model, test_loader):
    # Test the model on test set
    with torch.no_grad():
        y_true = []
        y_pred = []
        correct = 0
        total = 0
        for i, (inputs, labels) in enumerate(test_loader):
            inputs = inputs.reshape(-1, sequence_length, input_size).to(device)
            labels = labels.reshape(-1).to(device)
            outputs = model(inputs)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            y_true.append(labels.item())
            y_pred.append(predicted.item())
        
        accuracy = (correct/total)*100
        print('Final accuracy is {} %'.format(accuracy))
        
        plot_confusion_matrix([y_true], [y_pred], LABELS)
        save('test_confusion_matrix' + '.png')

    # Save the modal checkpoint
    torch.save(model.state_dict(), 'DeepNAR_model.ckpt')
    return accuracy


def main(num):
    accuracylist = []
    modellist = []
    for i in range(num):
        accuracy, model, test_loader = training_model(i)
        accuracylist.append(accuracy)
        modellist.append(model)
    index = accuracylist.index(max(accuracylist))
    print('Choose No.{} model as test model with {} % Dev accuracy.'.format(index+1, max(accuracylist)))
    best_model = modellist[index]
    test_accuracy = test_model(best_model, test_loader)
    
    return test_accuracy
# Out:
#   File "<ipython-input-14-503f827ecace>", line 203
#     accuracy = correct/total)*100
#                             ^
# SyntaxError: invalid syntax

# %%
test_num = 5
test_accuracies = []
start = datetime.datetime.now()
for i in range(test_num):
    accuracy = main(num=TRIALS_NUM)
    test_accuracies.append(accuracy)
end = datetime.datetime.now()
print('[Cost Time]: total - {}s, each - {}s'.format(end-start, (end-start)/test_num))
print('{} times average accuracy - {}%'.format(test_num, max(test_accuracies)))
# Out:
# (528, 36)
# Test [1], Epoch [2/60], Loss: 1.5237
# Test [1], Epoch [4/60], Loss: 1.3803
# Test [1], Epoch [6/60], Loss: 1.3919
# Test [1], Epoch [8/60], Loss: 1.4143
# Test [1], Epoch [10/60], Loss: 1.3810
# Test [1], Epoch [12/60], Loss: 1.3728
# Test [1], Epoch [14/60], Loss: 1.4205
# Test [1], Epoch [16/60], Loss: 1.3683
# Test [1], Epoch [18/60], Loss: 1.3902
# Test [1], Epoch [20/60], Loss: 1.4181
# Test [1], Epoch [22/60], Loss: 1.3939
# Test [1], Epoch [24/60], Loss: 1.3581
# Test [1], Epoch [26/60], Loss: 1.3702
# Test [1], Epoch [28/60], Loss: 1.4098
# Test [1], Epoch [30/60], Loss: 1.3296
# Test [1], Epoch [32/60], Loss: 1.3447
# Test [1], Epoch [34/60], Loss: 1.3520
# Test [1], Epoch [36/60], Loss: 1.3890
# Test [1], Epoch [38/60], Loss: 1.4006
# Test [1], Epoch [40/60], Loss: 1.3932
# Test [1], Epoch [42/60], Loss: 1.3390
# Test [1], Epoch [44/60], Loss: 1.3478
# Test [1], Epoch [46/60], Loss: 1.3400
# Test [1], Epoch [48/60], Loss: 1.3359
# Test [1], Epoch [50/60], Loss: 1.4203
# Test [1], Epoch [52/60], Loss: 1.3943
# Test [1], Epoch [54/60], Loss: 1.4153
# Test [1], Epoch [56/60], Loss: 1.3749
# Test [1], Epoch [58/60], Loss: 1.3417
# Test [1], Epoch [60/60], Loss: 1.3879
# Dev accuracy of the No.1 model on dev action samples: 28.125 %
# (528, 36)
# Test [2], Epoch [2/60], Loss: 1.4665
# Test [2], Epoch [4/60], Loss: 1.4652
# Test [2], Epoch [6/60], Loss: nan
# Test [2], Epoch [8/60], Loss: nan
# Test [2], Epoch [10/60], Loss: nan
# Test [2], Epoch [12/60], Loss: nan
# Test [2], Epoch [14/60], Loss: nan
# Test [2], Epoch [16/60], Loss: nan
# Test [2], Epoch [18/60], Loss: nan
# Test [2], Epoch [20/60], Loss: nan
# Test [2], Epoch [22/60], Loss: nan
# Test [2], Epoch [24/60], Loss: nan
# Test [2], Epoch [26/60], Loss: nan
# Test [2], Epoch [28/60], Loss: nan
# Test [2], Epoch [30/60], Loss: nan
# Test [2], Epoch [32/60], Loss: nan
# Test [2], Epoch [34/60], Loss: nan
# Test [2], Epoch [36/60], Loss: nan
# Test [2], Epoch [38/60], Loss: nan
# Test [2], Epoch [40/60], Loss: nan
# Test [2], Epoch [42/60], Loss: nan
# Test [2], Epoch [44/60], Loss: nan
# Test [2], Epoch [46/60], Loss: nan
# Test [2], Epoch [48/60], Loss: nan
# Test [2], Epoch [50/60], Loss: nan
# Test [2], Epoch [52/60], Loss: nan
# Test [2], Epoch [54/60], Loss: nan
# Test [2], Epoch [56/60], Loss: nan
# Test [2], Epoch [58/60], Loss: nan
# Test [2], Epoch [60/60], Loss: nan
# Dev accuracy of the No.2 model on dev action samples: 25.0 %
# (528, 36)
# Test [3], Epoch [2/60], Loss: 1.3942
# Test [3], Epoch [4/60], Loss: 1.3845
# Test [3], Epoch [6/60], Loss: 1.5113
# Test [3], Epoch [8/60], Loss: 1.6619
# Test [3], Epoch [10/60], Loss: 1.5478
# Test [3], Epoch [12/60], Loss: 1.3810
# Test [3], Epoch [14/60], Loss: 1.4698
# Test [3], Epoch [16/60], Loss: 1.3934
# Test [3], Epoch [18/60], Loss: 1.4021
# Test [3], Epoch [20/60], Loss: 1.5656
# Test [3], Epoch [22/60], Loss: 1.5468
# Test [3], Epoch [24/60], Loss: 1.4484
# Test [3], Epoch [26/60], Loss: 1.4202
# Test [3], Epoch [28/60], Loss: 1.4037
# Test [3], Epoch [30/60], Loss: 1.4054
# Test [3], Epoch [32/60], Loss: 1.3990
# Test [3], Epoch [34/60], Loss: 1.4010
# Test [3], Epoch [36/60], Loss: 1.4182
# Test [3], Epoch [38/60], Loss: 1.4136
# Test [3], Epoch [40/60], Loss: 1.4176
# Test [3], Epoch [42/60], Loss: 1.4190
# Test [3], Epoch [44/60], Loss: 1.3893
# Test [3], Epoch [46/60], Loss: 1.3798
# Test [3], Epoch [48/60], Loss: 1.3871
# Test [3], Epoch [50/60], Loss: 1.4047
# Test [3], Epoch [52/60], Loss: 1.4287
# Test [3], Epoch [54/60], Loss: 1.4138
# Test [3], Epoch [56/60], Loss: 1.4345
# Test [3], Epoch [58/60], Loss: 1.4162
# Test [3], Epoch [60/60], Loss: 1.4565
# Dev accuracy of the No.3 model on dev action samples: 25.0 %
# (528, 36)
# Test [4], Epoch [2/60], Loss: 3.2448
# Test [4], Epoch [4/60], Loss: 1.4394
# Test [4], Epoch [6/60], Loss: 1.3566
# Test [4], Epoch [8/60], Loss: 1.3917
# Test [4], Epoch [10/60], Loss: 1.3268
# Test [4], Epoch [12/60], Loss: 1.3563
# Test [4], Epoch [14/60], Loss: 1.3251
# Test [4], Epoch [16/60], Loss: 1.4160
# Test [4], Epoch [18/60], Loss: 1.2039
# Test [4], Epoch [20/60], Loss: 1.1413
# Test [4], Epoch [22/60], Loss: 0.9417
# Test [4], Epoch [24/60], Loss: 0.8034
# Test [4], Epoch [26/60], Loss: 0.6333
# Test [4], Epoch [28/60], Loss: 0.5998
# Test [4], Epoch [30/60], Loss: 0.5010
# Test [4], Epoch [32/60], Loss: 0.4071
# Test [4], Epoch [34/60], Loss: 0.4820
# Test [4], Epoch [36/60], Loss: 0.4774
# Test [4], Epoch [38/60], Loss: 0.3472
# Test [4], Epoch [40/60], Loss: 0.4010
# Test [4], Epoch [42/60], Loss: 0.3368
# Test [4], Epoch [44/60], Loss: 0.4017
# Test [4], Epoch [46/60], Loss: 0.3193
# Test [4], Epoch [48/60], Loss: 0.3706
# Test [4], Epoch [50/60], Loss: 0.3358
# Test [4], Epoch [52/60], Loss: 0.3189
# Test [4], Epoch [54/60], Loss: 0.3277
# Test [4], Epoch [56/60], Loss: 0.4333
# Test [4], Epoch [58/60], Loss: 0.3884
# Test [4], Epoch [60/60], Loss: 0.3521
# Dev accuracy of the No.4 model on dev action samples: 71.875 %
# (528, 36)
# Test [5], Epoch [2/60], Loss: 1.6150
# Test [5], Epoch [4/60], Loss: 1.3777
# Test [5], Epoch [6/60], Loss: 1.3723
# Test [5], Epoch [8/60], Loss: 1.4106
# Test [5], Epoch [10/60], Loss: 1.4642
# Test [5], Epoch [12/60], Loss: 1.4655
# Test [5], Epoch [14/60], Loss: 1.4242
# Test [5], Epoch [16/60], Loss: 1.4403
# Test [5], Epoch [18/60], Loss: 1.4327
# Test [5], Epoch [20/60], Loss: 1.4119
# Test [5], Epoch [22/60], Loss: 1.4419
# Test [5], Epoch [24/60], Loss: 1.4451
# Test [5], Epoch [26/60], Loss: 1.3929
# Test [5], Epoch [28/60], Loss: 1.3909
# Test [5], Epoch [30/60], Loss: 1.3957
# Test [5], Epoch [32/60], Loss: 1.3979
# Test [5], Epoch [34/60], Loss: 1.4031
# Test [5], Epoch [36/60], Loss: 1.3938
# Test [5], Epoch [38/60], Loss: 1.4315
# Test [5], Epoch [40/60], Loss: 1.4258
# Test [5], Epoch [42/60], Loss: 1.4054
# Test [5], Epoch [44/60], Loss: 1.4223
# Test [5], Epoch [46/60], Loss: 1.3862
# Test [5], Epoch [48/60], Loss: 1.4710
# Test [5], Epoch [50/60], Loss: 1.4171
# Test [5], Epoch [52/60], Loss: 1.3966
# Test [5], Epoch [54/60], Loss: 1.4134
# Test [5], Epoch [56/60], Loss: 1.4198
# Test [5], Epoch [58/60], Loss: 1.3947
# Test [5], Epoch [60/60], Loss: 1.3900
# Dev accuracy of the No.5 model on dev action samples: 25.0 %
# Choose No.4 model as test model with 71.875 % Dev accuracy.
# Final accuracy is 68.75 %
# (528, 36)
# Test [1], Epoch [2/60], Loss: 1.4309
# Test [1], Epoch [4/60], Loss: 1.5912
# Test [1], Epoch [6/60], Loss: 1.5123
# Test [1], Epoch [8/60], Loss: 1.3681
# Test [1], Epoch [10/60], Loss: 1.3677
# Test [1], Epoch [12/60], Loss: 1.4034
# Test [1], Epoch [14/60], Loss: 1.4142
# Test [1], Epoch [16/60], Loss: 1.3809
# Test [1], Epoch [18/60], Loss: 1.3777
# Test [1], Epoch [20/60], Loss: 1.4089
# Test [1], Epoch [22/60], Loss: 1.3536
# Test [1], Epoch [24/60], Loss: 1.4048
# Test [1], Epoch [26/60], Loss: 1.3844
# Test [1], Epoch [28/60], Loss: 1.3917
# Test [1], Epoch [30/60], Loss: 1.3957
# Test [1], Epoch [32/60], Loss: 1.4070
# Test [1], Epoch [34/60], Loss: 1.3743
# Test [1], Epoch [36/60], Loss: 1.3882
# Test [1], Epoch [38/60], Loss: 1.3763
# Test [1], Epoch [40/60], Loss: 1.3919
# Test [1], Epoch [42/60], Loss: 1.3907
# Test [1], Epoch [44/60], Loss: 1.3933
# Test [1], Epoch [46/60], Loss: 1.3643
# Test [1], Epoch [48/60], Loss: 1.3867
# Test [1], Epoch [50/60], Loss: 1.3877
# Test [1], Epoch [52/60], Loss: 1.4105
# Test [1], Epoch [54/60], Loss: 1.3795
# Test [1], Epoch [56/60], Loss: 1.3680
# Test [1], Epoch [58/60], Loss: 1.3668
# Test [1], Epoch [60/60], Loss: 1.3813
# Dev accuracy of the No.1 model on dev action samples: 21.875 %
# (528, 36)
# Test [2], Epoch [2/60], Loss: 1.4486
# Test [2], Epoch [4/60], Loss: 1.4461
# Test [2], Epoch [6/60], Loss: 1.4723
# Test [2], Epoch [8/60], Loss: 1.4012
# Test [2], Epoch [10/60], Loss: 1.3762
# Test [2], Epoch [12/60], Loss: 1.5042
# Test [2], Epoch [14/60], Loss: 1.4312
# Test [2], Epoch [16/60], Loss: 1.2531
# Test [2], Epoch [18/60], Loss: 1.1996
# Test [2], Epoch [20/60], Loss: 1.0729
# Test [2], Epoch [22/60], Loss: 0.9666
# Test [2], Epoch [24/60], Loss: 0.7910
# Test [2], Epoch [26/60], Loss: 0.6479
# Test [2], Epoch [28/60], Loss: 0.6011
# Test [2], Epoch [30/60], Loss: 0.3472
# Test [2], Epoch [32/60], Loss: 0.4655
# Test [2], Epoch [34/60], Loss: 0.2694
# Test [2], Epoch [36/60], Loss: 0.2142
# Test [2], Epoch [38/60], Loss: 0.2225
# Test [2], Epoch [40/60], Loss: 0.0916
# Test [2], Epoch [42/60], Loss: 0.1172
# Test [2], Epoch [44/60], Loss: 0.0768
# Test [2], Epoch [46/60], Loss: 0.0791
# Test [2], Epoch [48/60], Loss: 0.0338
# Test [2], Epoch [50/60], Loss: 0.0637
# Test [2], Epoch [52/60], Loss: 0.0499
# Test [2], Epoch [54/60], Loss: 0.0623
# Test [2], Epoch [56/60], Loss: 0.0192
# Test [2], Epoch [58/60], Loss: 0.0205
# Test [2], Epoch [60/60], Loss: 0.0111
# Dev accuracy of the No.2 model on dev action samples: 78.125 %
# (528, 36)
# Test [3], Epoch [2/60], Loss: 1.6175
# Test [3], Epoch [4/60], Loss: 1.3924
# Test [3], Epoch [6/60], Loss: 1.4258
# Test [3], Epoch [8/60], Loss: 1.3971
# Test [3], Epoch [10/60], Loss: 1.4231
# Test [3], Epoch [12/60], Loss: 1.3992
# Test [3], Epoch [14/60], Loss: 1.3927
# Test [3], Epoch [16/60], Loss: 1.3877
# Test [3], Epoch [18/60], Loss: 1.3881
# Test [3], Epoch [20/60], Loss: 1.3920
# Test [3], Epoch [22/60], Loss: 1.3873
# Test [3], Epoch [24/60], Loss: 1.3884
# Test [3], Epoch [26/60], Loss: 1.3866
# Test [3], Epoch [28/60], Loss: 1.3874
# Test [3], Epoch [30/60], Loss: 1.3853
# Test [3], Epoch [32/60], Loss: 1.3885
# Test [3], Epoch [34/60], Loss: 1.3913
# Test [3], Epoch [36/60], Loss: 1.3872
# Test [3], Epoch [38/60], Loss: 1.3911
# Test [3], Epoch [40/60], Loss: 1.3882
# Test [3], Epoch [42/60], Loss: 1.3859
# Test [3], Epoch [44/60], Loss: 1.3868
# Test [3], Epoch [46/60], Loss: 1.3880
# Test [3], Epoch [48/60], Loss: 1.3862
# Test [3], Epoch [50/60], Loss: 1.3855
# Test [3], Epoch [52/60], Loss: 1.3871
# Test [3], Epoch [54/60], Loss: 1.3890
# Test [3], Epoch [56/60], Loss: 1.3932
# Test [3], Epoch [58/60], Loss: 1.3856
# Test [3], Epoch [60/60], Loss: 1.3924
# Dev accuracy of the No.3 model on dev action samples: 25.0 %
# (528, 36)
# Test [4], Epoch [2/60], Loss: 1.4322
# Test [4], Epoch [4/60], Loss: 1.4707
# Test [4], Epoch [6/60], Loss: 1.5145
# Test [4], Epoch [8/60], Loss: 1.4570
# Test [4], Epoch [10/60], Loss: 1.3683
# Test [4], Epoch [12/60], Loss: 1.3804
# Test [4], Epoch [14/60], Loss: 1.3542
# Test [4], Epoch [16/60], Loss: 1.3901
# Test [4], Epoch [18/60], Loss: 1.4561
# Test [4], Epoch [20/60], Loss: 1.3790
# Test [4], Epoch [22/60], Loss: 1.4180
# Test [4], Epoch [24/60], Loss: 1.3929
# Test [4], Epoch [26/60], Loss: 1.3971
# Test [4], Epoch [28/60], Loss: 1.4393
# Test [4], Epoch [30/60], Loss: 1.3723
# Test [4], Epoch [32/60], Loss: 1.2966
# Test [4], Epoch [34/60], Loss: 1.3756
# Test [4], Epoch [36/60], Loss: 1.4274
# Test [4], Epoch [38/60], Loss: 1.3576
# Test [4], Epoch [40/60], Loss: 1.3429
# Test [4], Epoch [42/60], Loss: 1.4240
# Test [4], Epoch [44/60], Loss: 1.3800
# Test [4], Epoch [46/60], Loss: 1.3091
# Test [4], Epoch [48/60], Loss: 1.2965
# Test [4], Epoch [50/60], Loss: 1.3944
# Test [4], Epoch [52/60], Loss: 1.3232
# Test [4], Epoch [54/60], Loss: 1.3444
# Test [4], Epoch [56/60], Loss: 1.3404
# Test [4], Epoch [58/60], Loss: 1.3607
# Test [4], Epoch [60/60], Loss: 1.3648
# Dev accuracy of the No.4 model on dev action samples: 34.375 %
# (528, 36)
# Test [5], Epoch [2/60], Loss: 1.4527
# Test [5], Epoch [4/60], Loss: 1.3820
# Test [5], Epoch [6/60], Loss: 1.4272
# Test [5], Epoch [8/60], Loss: 1.4929
# Test [5], Epoch [10/60], Loss: 1.3230
# Test [5], Epoch [12/60], Loss: 1.4657
# Test [5], Epoch [14/60], Loss: 1.3441
# Test [5], Epoch [16/60], Loss: 1.3912
# Test [5], Epoch [18/60], Loss: 1.3734
# Test [5], Epoch [20/60], Loss: 1.3356
# Test [5], Epoch [22/60], Loss: 1.4442
# Test [5], Epoch [24/60], Loss: 1.4002
# Test [5], Epoch [26/60], Loss: 1.4229
# Test [5], Epoch [28/60], Loss: 1.3816
# Test [5], Epoch [30/60], Loss: 1.3865
# Test [5], Epoch [32/60], Loss: 1.3873
# Test [5], Epoch [34/60], Loss: 1.4111
# Test [5], Epoch [36/60], Loss: 1.4174
# Test [5], Epoch [38/60], Loss: 1.4370
# Test [5], Epoch [40/60], Loss: 1.4545
# Test [5], Epoch [42/60], Loss: 1.4024
# Test [5], Epoch [44/60], Loss: 1.3504
# Test [5], Epoch [46/60], Loss: 1.3704
# Test [5], Epoch [48/60], Loss: 1.4221
# Test [5], Epoch [50/60], Loss: 1.3320
# Test [5], Epoch [52/60], Loss: 1.3636
# Test [5], Epoch [54/60], Loss: 1.3105
# Test [5], Epoch [56/60], Loss: 1.5797
# Test [5], Epoch [58/60], Loss: 1.3297
# Test [5], Epoch [60/60], Loss: 1.3747
# Dev accuracy of the No.5 model on dev action samples: 25.0 %
# /home/zhong/anaconda3/envs/DeepNAR/lib/python3.7/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# Choose No.2 model as test model with 78.125 % Dev accuracy.
# Final accuracy is 53.125 %
# (528, 36)
# Test [1], Epoch [2/60], Loss: 1.4877
# Test [1], Epoch [4/60], Loss: 1.3938
# Test [1], Epoch [6/60], Loss: 1.4617
# Test [1], Epoch [8/60], Loss: 1.4105
# Test [1], Epoch [10/60], Loss: 1.3822
# Test [1], Epoch [12/60], Loss: 1.3891
# Test [1], Epoch [14/60], Loss: 1.4351
# Test [1], Epoch [16/60], Loss: 1.3760
# Test [1], Epoch [18/60], Loss: 1.4167
# Test [1], Epoch [20/60], Loss: 1.4244
# Test [1], Epoch [22/60], Loss: 1.3862
# Test [1], Epoch [24/60], Loss: 1.4284
# Test [1], Epoch [26/60], Loss: 1.4384
# Test [1], Epoch [28/60], Loss: 1.4206
# Test [1], Epoch [30/60], Loss: 1.3950
# Test [1], Epoch [32/60], Loss: 1.3754
# Test [1], Epoch [34/60], Loss: 1.3913
# Test [1], Epoch [36/60], Loss: 1.3986
# Test [1], Epoch [38/60], Loss: 1.3855
# Test [1], Epoch [40/60], Loss: 1.4249
# Test [1], Epoch [42/60], Loss: 1.3853
# Test [1], Epoch [44/60], Loss: 1.3947
# Test [1], Epoch [46/60], Loss: 1.3832
# Test [1], Epoch [48/60], Loss: 1.4073
# Test [1], Epoch [50/60], Loss: 1.3868
# Test [1], Epoch [52/60], Loss: 1.4207
# Test [1], Epoch [54/60], Loss: 1.3934
# Test [1], Epoch [56/60], Loss: 1.3868
# Test [1], Epoch [58/60], Loss: 1.4248
# Test [1], Epoch [60/60], Loss: 1.3914
# Dev accuracy of the No.1 model on dev action samples: 28.125 %
# (528, 36)
# Test [2], Epoch [2/60], Loss: 1.4151
# Test [2], Epoch [4/60], Loss: 1.4697
# Test [2], Epoch [6/60], Loss: 1.4367
# Test [2], Epoch [8/60], Loss: 1.3983
# Test [2], Epoch [10/60], Loss: 1.4017
# Test [2], Epoch [12/60], Loss: 1.3899
# Test [2], Epoch [14/60], Loss: 1.3869
# Test [2], Epoch [16/60], Loss: 1.3996
# Test [2], Epoch [18/60], Loss: 1.3912
# Test [2], Epoch [20/60], Loss: 1.3920
# Test [2], Epoch [22/60], Loss: 1.3968
# Test [2], Epoch [24/60], Loss: 1.4134
# Test [2], Epoch [26/60], Loss: 1.3869
# Test [2], Epoch [28/60], Loss: 1.4313
# Test [2], Epoch [30/60], Loss: 1.3909
# Test [2], Epoch [32/60], Loss: 1.3829
# Test [2], Epoch [34/60], Loss: 1.3854
# Test [2], Epoch [36/60], Loss: 1.3902
# Test [2], Epoch [38/60], Loss: 1.3892
# Test [2], Epoch [40/60], Loss: 1.3896
# Test [2], Epoch [42/60], Loss: 1.3876
# Test [2], Epoch [44/60], Loss: 1.3907
# Test [2], Epoch [46/60], Loss: 1.3888
# Test [2], Epoch [48/60], Loss: 1.3911
# Test [2], Epoch [50/60], Loss: 1.3940
# Test [2], Epoch [52/60], Loss: 1.3865
# Test [2], Epoch [54/60], Loss: 1.3864
# Test [2], Epoch [56/60], Loss: 1.3879
# Test [2], Epoch [58/60], Loss: 1.3916
# Test [2], Epoch [60/60], Loss: 1.3867
# Dev accuracy of the No.2 model on dev action samples: 25.0 %
# (528, 36)
# Test [3], Epoch [2/60], Loss: 1.5140
# Test [3], Epoch [4/60], Loss: 1.4161
# Test [3], Epoch [6/60], Loss: 1.4136
# Test [3], Epoch [8/60], Loss: 1.4324
# Test [3], Epoch [10/60], Loss: 1.2730
# Test [3], Epoch [12/60], Loss: 1.2467
# Test [3], Epoch [14/60], Loss: 1.2589
# Test [3], Epoch [16/60], Loss: 1.3330
# Test [3], Epoch [18/60], Loss: 1.3465
# Test [3], Epoch [20/60], Loss: 1.3790
# Test [3], Epoch [22/60], Loss: 1.3072
# Test [3], Epoch [24/60], Loss: 1.2079
# Test [3], Epoch [26/60], Loss: 1.2263
# Test [3], Epoch [28/60], Loss: 1.3881
# Test [3], Epoch [30/60], Loss: 1.2646
# Test [3], Epoch [32/60], Loss: 1.3872
# Test [3], Epoch [34/60], Loss: 1.2332
# Test [3], Epoch [36/60], Loss: 1.2229
# Test [3], Epoch [38/60], Loss: 1.2754
# Test [3], Epoch [40/60], Loss: 1.2214
# Test [3], Epoch [42/60], Loss: 1.1778
# Test [3], Epoch [44/60], Loss: 1.2985
# Test [3], Epoch [46/60], Loss: 1.3118
# Test [3], Epoch [48/60], Loss: 1.2490
# Test [3], Epoch [50/60], Loss: 1.2908
# Test [3], Epoch [52/60], Loss: 1.0897
# Test [3], Epoch [54/60], Loss: 1.2589
# Test [3], Epoch [56/60], Loss: 1.3098
# Test [3], Epoch [58/60], Loss: 1.0771
# Test [3], Epoch [60/60], Loss: 1.2255
# Dev accuracy of the No.3 model on dev action samples: 18.75 %
# (528, 36)
# Test [4], Epoch [2/60], Loss: 1.3912
# Test [4], Epoch [4/60], Loss: 1.3934
# Test [4], Epoch [6/60], Loss: 1.3783
# Test [4], Epoch [8/60], Loss: 1.3945
# Test [4], Epoch [10/60], Loss: 1.4089
# Test [4], Epoch [12/60], Loss: 1.3927
# Test [4], Epoch [14/60], Loss: 1.3796
# Test [4], Epoch [16/60], Loss: 1.3914
# Test [4], Epoch [18/60], Loss: 1.3845
# Test [4], Epoch [20/60], Loss: 1.4542
# Test [4], Epoch [22/60], Loss: 1.3939
# Test [4], Epoch [24/60], Loss: 1.3202
# Test [4], Epoch [26/60], Loss: 1.3599
# Test [4], Epoch [28/60], Loss: 1.3895
# Test [4], Epoch [30/60], Loss: 1.3498
# Test [4], Epoch [32/60], Loss: 1.3471
# Test [4], Epoch [34/60], Loss: 1.4304
# Test [4], Epoch [36/60], Loss: 1.3736
# Test [4], Epoch [38/60], Loss: 1.3684
# Test [4], Epoch [40/60], Loss: 1.3327
# Test [4], Epoch [42/60], Loss: 1.3579
# Test [4], Epoch [44/60], Loss: 1.3787
# Test [4], Epoch [46/60], Loss: 1.3509
# Test [4], Epoch [48/60], Loss: 1.3345
# Test [4], Epoch [50/60], Loss: 1.3123
# Test [4], Epoch [52/60], Loss: 1.4374
# Test [4], Epoch [54/60], Loss: 1.3755
# Test [4], Epoch [56/60], Loss: 1.3523
# Test [4], Epoch [58/60], Loss: 1.3602
# Test [4], Epoch [60/60], Loss: 1.3850
# Dev accuracy of the No.4 model on dev action samples: 28.125 %
# (528, 36)
# Test [5], Epoch [2/60], Loss: 1.3842
# Test [5], Epoch [4/60], Loss: 1.4534
# Test [5], Epoch [6/60], Loss: 1.4338
# Test [5], Epoch [8/60], Loss: 1.3926
# Test [5], Epoch [10/60], Loss: 1.4382
# Test [5], Epoch [12/60], Loss: 1.3985
# Test [5], Epoch [14/60], Loss: 1.3815
# Test [5], Epoch [16/60], Loss: 1.3615
# Test [5], Epoch [18/60], Loss: 1.3355
# Test [5], Epoch [20/60], Loss: 1.2882
# Test [5], Epoch [22/60], Loss: 1.3453
# Test [5], Epoch [24/60], Loss: 1.3016
# Test [5], Epoch [26/60], Loss: 1.3571
# Test [5], Epoch [28/60], Loss: 1.3519
# Test [5], Epoch [30/60], Loss: 1.3741
# Test [5], Epoch [32/60], Loss: 1.3802
# Test [5], Epoch [34/60], Loss: 1.3959
# Test [5], Epoch [36/60], Loss: 1.4300
# Test [5], Epoch [38/60], Loss: 1.3575
# Test [5], Epoch [40/60], Loss: 1.2794
# Test [5], Epoch [42/60], Loss: 1.3108
# Test [5], Epoch [44/60], Loss: 1.3895
# Test [5], Epoch [46/60], Loss: 1.1508
# Test [5], Epoch [48/60], Loss: 1.4002
# Test [5], Epoch [50/60], Loss: 1.3037
# Test [5], Epoch [52/60], Loss: 1.2068
# Test [5], Epoch [54/60], Loss: 1.3478
# Test [5], Epoch [56/60], Loss: 1.2783
# Test [5], Epoch [58/60], Loss: 1.2783
# Test [5], Epoch [60/60], Loss: 1.1923
# Dev accuracy of the No.5 model on dev action samples: 21.875 %
# Choose No.1 model as test model with 28.125 % Dev accuracy.
# Final accuracy is 28.125 %
# (528, 36)
# Test [1], Epoch [2/60], Loss: 1.3800
# Test [1], Epoch [4/60], Loss: 1.4644
# Test [1], Epoch [6/60], Loss: 1.3973
# Test [1], Epoch [8/60], Loss: 1.3396
# Test [1], Epoch [10/60], Loss: 0.7232
# Test [1], Epoch [12/60], Loss: 0.1601
# Test [1], Epoch [14/60], Loss: 0.0106
# Test [1], Epoch [16/60], Loss: 0.0070
# Test [1], Epoch [18/60], Loss: 0.0030
# Test [1], Epoch [20/60], Loss: 0.0016
# Test [1], Epoch [22/60], Loss: 0.0017
# Test [1], Epoch [24/60], Loss: 0.0011
# Test [1], Epoch [26/60], Loss: 0.0015
# Test [1], Epoch [28/60], Loss: 0.0014
# Test [1], Epoch [30/60], Loss: 0.0013
# Test [1], Epoch [32/60], Loss: 0.0006
# Test [1], Epoch [34/60], Loss: 0.0007
# Test [1], Epoch [36/60], Loss: 0.0005
# Test [1], Epoch [38/60], Loss: 0.0005
# Test [1], Epoch [40/60], Loss: 0.0006
# Test [1], Epoch [42/60], Loss: 0.0007
# Test [1], Epoch [44/60], Loss: 0.0004
# Test [1], Epoch [46/60], Loss: 0.0004
# Test [1], Epoch [48/60], Loss: 0.0005
# Test [1], Epoch [50/60], Loss: 0.0004
# Test [1], Epoch [52/60], Loss: 0.0004
# Test [1], Epoch [54/60], Loss: 0.0004
# Test [1], Epoch [56/60], Loss: 0.0003
# Test [1], Epoch [58/60], Loss: 0.0003
# Test [1], Epoch [60/60], Loss: 0.0003
# Dev accuracy of the No.1 model on dev action samples: 81.25 %
# (528, 36)
# Test [2], Epoch [2/60], Loss: 1.3988
# Test [2], Epoch [4/60], Loss: 1.4522
# Test [2], Epoch [6/60], Loss: 1.4583
# Test [2], Epoch [8/60], Loss: 1.3867
# Test [2], Epoch [10/60], Loss: 1.4246
# Test [2], Epoch [12/60], Loss: 1.4073
# Test [2], Epoch [14/60], Loss: 1.4354
# Test [2], Epoch [16/60], Loss: 1.4327
# Test [2], Epoch [18/60], Loss: 1.4140
# Test [2], Epoch [20/60], Loss: 1.4123
# Test [2], Epoch [22/60], Loss: 1.4801
# Test [2], Epoch [24/60], Loss: 1.4468
# Test [2], Epoch [26/60], Loss: 1.3990
# Test [2], Epoch [28/60], Loss: 1.3949
# Test [2], Epoch [30/60], Loss: 1.4255
# Test [2], Epoch [32/60], Loss: 1.4165
# Test [2], Epoch [34/60], Loss: 1.3416
# Test [2], Epoch [36/60], Loss: 1.3724
# Test [2], Epoch [38/60], Loss: 1.4083
# Test [2], Epoch [40/60], Loss: 1.4482
# Test [2], Epoch [42/60], Loss: 1.4052
# Test [2], Epoch [44/60], Loss: 1.4539
# Test [2], Epoch [46/60], Loss: 1.3705
# Test [2], Epoch [48/60], Loss: 1.3917
# Test [2], Epoch [50/60], Loss: 1.3977
# Test [2], Epoch [52/60], Loss: 1.3420
# Test [2], Epoch [54/60], Loss: 1.3743
# Test [2], Epoch [56/60], Loss: 1.4207
# Test [2], Epoch [58/60], Loss: 1.3766
# Test [2], Epoch [60/60], Loss: 1.3758
# Dev accuracy of the No.2 model on dev action samples: 37.5 %
# (528, 36)
# Test [3], Epoch [2/60], Loss: 1.7566
# Test [3], Epoch [4/60], Loss: 1.5665
# Test [3], Epoch [6/60], Loss: 1.4270
# Test [3], Epoch [8/60], Loss: 1.3907
# Test [3], Epoch [10/60], Loss: 1.4835
# Test [3], Epoch [12/60], Loss: 1.3333
# Test [3], Epoch [14/60], Loss: 1.4268
# Test [3], Epoch [16/60], Loss: 1.3041
# Test [3], Epoch [18/60], Loss: 1.2603
# Test [3], Epoch [20/60], Loss: 1.2620
# Test [3], Epoch [22/60], Loss: 1.2159
# Test [3], Epoch [24/60], Loss: 1.3379
# Test [3], Epoch [26/60], Loss: 1.1694
# Test [3], Epoch [28/60], Loss: 1.1946
# Test [3], Epoch [30/60], Loss: 1.1501
# Test [3], Epoch [32/60], Loss: 1.1560
# Test [3], Epoch [34/60], Loss: 1.1184
# Test [3], Epoch [36/60], Loss: 1.2690
# Test [3], Epoch [38/60], Loss: 1.1329
# Test [3], Epoch [40/60], Loss: 1.0810
# Test [3], Epoch [42/60], Loss: 1.0354
# Test [3], Epoch [44/60], Loss: 1.0912
# Test [3], Epoch [46/60], Loss: 1.0461
# Test [3], Epoch [48/60], Loss: 1.0215
# Test [3], Epoch [50/60], Loss: 1.0580
# Test [3], Epoch [52/60], Loss: 1.0619
# Test [3], Epoch [54/60], Loss: 0.9545
# Test [3], Epoch [56/60], Loss: 0.9832
# Test [3], Epoch [58/60], Loss: 1.0312
# Test [3], Epoch [60/60], Loss: 1.0176
# Dev accuracy of the No.3 model on dev action samples: 56.25 %
# (528, 36)
# Test [4], Epoch [2/60], Loss: 1.5568
# Test [4], Epoch [4/60], Loss: 1.5242
# Test [4], Epoch [6/60], Loss: 1.4780
# Test [4], Epoch [8/60], Loss: 1.4089
# Test [4], Epoch [10/60], Loss: 1.3605
# Test [4], Epoch [12/60], Loss: 1.2704
# Test [4], Epoch [14/60], Loss: 1.2171
# Test [4], Epoch [16/60], Loss: 0.9147
# Test [4], Epoch [18/60], Loss: 0.7273
# Test [4], Epoch [20/60], Loss: 0.6091
# Test [4], Epoch [22/60], Loss: 0.4435
# Test [4], Epoch [24/60], Loss: 0.3348
# Test [4], Epoch [26/60], Loss: 0.1981
# Test [4], Epoch [28/60], Loss: 0.1309
# Test [4], Epoch [30/60], Loss: 0.2165
# Test [4], Epoch [32/60], Loss: 0.1235
# Test [4], Epoch [34/60], Loss: 0.1049
# Test [4], Epoch [36/60], Loss: 0.0604
# Test [4], Epoch [38/60], Loss: 0.0571
# Test [4], Epoch [40/60], Loss: 0.2325
# Test [4], Epoch [42/60], Loss: 0.0864
# Test [4], Epoch [44/60], Loss: 0.0781
# Test [4], Epoch [46/60], Loss: 0.0385
# Test [4], Epoch [48/60], Loss: 0.0280
# Test [4], Epoch [50/60], Loss: 0.0337
# Test [4], Epoch [52/60], Loss: 0.0215
# Test [4], Epoch [54/60], Loss: 0.0111
# Test [4], Epoch [56/60], Loss: 0.0150
# Test [4], Epoch [58/60], Loss: 0.0156
# Test [4], Epoch [60/60], Loss: 0.0129
# Dev accuracy of the No.4 model on dev action samples: 84.375 %
# (528, 36)
# Test [5], Epoch [2/60], Loss: 1.5211
# Test [5], Epoch [4/60], Loss: 1.4605
# Test [5], Epoch [6/60], Loss: 1.4215
# Test [5], Epoch [8/60], Loss: 1.3375
# Test [5], Epoch [10/60], Loss: 1.3169
# Test [5], Epoch [12/60], Loss: 1.3151
# Test [5], Epoch [14/60], Loss: 1.3575
# Test [5], Epoch [16/60], Loss: 1.3927
# Test [5], Epoch [18/60], Loss: 1.4084
# Test [5], Epoch [20/60], Loss: 1.4105
# Test [5], Epoch [22/60], Loss: 1.4062
# Test [5], Epoch [24/60], Loss: 1.3468
# Test [5], Epoch [26/60], Loss: 1.3815
# Test [5], Epoch [28/60], Loss: 1.3541
# Test [5], Epoch [30/60], Loss: 1.3968
# Test [5], Epoch [32/60], Loss: 1.3877
# Test [5], Epoch [34/60], Loss: 1.4242
# Test [5], Epoch [36/60], Loss: 1.5473
# Test [5], Epoch [38/60], Loss: 1.3957
# Test [5], Epoch [40/60], Loss: 1.3918
# Test [5], Epoch [42/60], Loss: 1.3305
# Test [5], Epoch [44/60], Loss: 1.3535
# Test [5], Epoch [46/60], Loss: 1.3675
# Test [5], Epoch [48/60], Loss: 1.3467
# Test [5], Epoch [50/60], Loss: 1.3613
# Test [5], Epoch [52/60], Loss: 1.3450
# Test [5], Epoch [54/60], Loss: 1.3742
# Test [5], Epoch [56/60], Loss: 1.3272
# Test [5], Epoch [58/60], Loss: 1.3530
# Test [5], Epoch [60/60], Loss: 1.4825
# Dev accuracy of the No.5 model on dev action samples: 28.125 %
# Choose No.4 model as test model with 84.375 % Dev accuracy.
# Final accuracy is 78.125 %
# (528, 36)
# Test [1], Epoch [2/60], Loss: 1.3973
# Test [1], Epoch [4/60], Loss: 1.3856
# Test [1], Epoch [6/60], Loss: 1.3584
# Test [1], Epoch [8/60], Loss: 1.3960
# Test [1], Epoch [10/60], Loss: 1.3753
# Test [1], Epoch [12/60], Loss: 1.3851
# Test [1], Epoch [14/60], Loss: 1.3709
# Test [1], Epoch [16/60], Loss: 1.4205
# Test [1], Epoch [18/60], Loss: 1.3714
# Test [1], Epoch [20/60], Loss: 1.3833
# Test [1], Epoch [22/60], Loss: 1.3528
# Test [1], Epoch [24/60], Loss: 1.3738
# Test [1], Epoch [26/60], Loss: 1.4042
# Test [1], Epoch [28/60], Loss: 1.3848
# Test [1], Epoch [30/60], Loss: 1.3909
# Test [1], Epoch [32/60], Loss: 1.3841
# Test [1], Epoch [34/60], Loss: 1.3701
# Test [1], Epoch [36/60], Loss: 1.3742
# Test [1], Epoch [38/60], Loss: 1.3573
# Test [1], Epoch [40/60], Loss: 1.3900
# Test [1], Epoch [42/60], Loss: 1.3605
# Test [1], Epoch [44/60], Loss: 1.4071
# Test [1], Epoch [46/60], Loss: 1.3802
# Test [1], Epoch [48/60], Loss: 1.3795
# Test [1], Epoch [50/60], Loss: 1.3712
# Test [1], Epoch [52/60], Loss: 1.3739
# Test [1], Epoch [54/60], Loss: 1.3605
# Test [1], Epoch [56/60], Loss: 1.3893
# Test [1], Epoch [58/60], Loss: 1.3674
# Test [1], Epoch [60/60], Loss: 1.3852
# Dev accuracy of the No.1 model on dev action samples: 21.875 %
# (528, 36)
# Test [2], Epoch [2/60], Loss: 2.4467
# Test [2], Epoch [4/60], Loss: 1.4173
# Test [2], Epoch [6/60], Loss: 1.4285
# Test [2], Epoch [8/60], Loss: 1.3912
# Test [2], Epoch [10/60], Loss: 1.3906
# Test [2], Epoch [12/60], Loss: 1.4113
# Test [2], Epoch [14/60], Loss: 1.4572
# Test [2], Epoch [16/60], Loss: 1.4540
# Test [2], Epoch [18/60], Loss: 1.5286
# Test [2], Epoch [20/60], Loss: 1.3700
# Test [2], Epoch [22/60], Loss: 1.4574
# Test [2], Epoch [24/60], Loss: 1.4088
# Test [2], Epoch [26/60], Loss: 1.4655
# Test [2], Epoch [28/60], Loss: 1.5576
# Test [2], Epoch [30/60], Loss: 1.3781
# Test [2], Epoch [32/60], Loss: 1.4514
# Test [2], Epoch [34/60], Loss: 1.3821
# Test [2], Epoch [36/60], Loss: 1.3963
# Test [2], Epoch [38/60], Loss: 1.4375
# Test [2], Epoch [40/60], Loss: 1.4368
# Test [2], Epoch [42/60], Loss: 1.4121
# Test [2], Epoch [44/60], Loss: 1.3902
# Test [2], Epoch [46/60], Loss: 1.4366
# Test [2], Epoch [48/60], Loss: 1.3912
# Test [2], Epoch [50/60], Loss: 1.3938
# Test [2], Epoch [52/60], Loss: 1.3908
# Test [2], Epoch [54/60], Loss: 1.4167
# Test [2], Epoch [56/60], Loss: 1.4240
# Test [2], Epoch [58/60], Loss: 1.4044
# Test [2], Epoch [60/60], Loss: 1.4488
# Dev accuracy of the No.2 model on dev action samples: 25.0 %
# (528, 36)
# Test [3], Epoch [2/60], Loss: 1.5010
# Test [3], Epoch [4/60], Loss: 1.4036
# Test [3], Epoch [6/60], Loss: 1.3926
# Test [3], Epoch [8/60], Loss: 1.4127
# Test [3], Epoch [10/60], Loss: 1.4500
# Test [3], Epoch [12/60], Loss: 1.4085
# Test [3], Epoch [14/60], Loss: 1.3788
# Test [3], Epoch [16/60], Loss: 1.3402
# Test [3], Epoch [18/60], Loss: 1.3966
# Test [3], Epoch [20/60], Loss: 1.4325
# Test [3], Epoch [22/60], Loss: 1.3438
# Test [3], Epoch [24/60], Loss: 1.3387
# Test [3], Epoch [26/60], Loss: 1.3599
# Test [3], Epoch [28/60], Loss: 1.3146
# Test [3], Epoch [30/60], Loss: 1.4042
# Test [3], Epoch [32/60], Loss: 1.3515
# Test [3], Epoch [34/60], Loss: 1.4197
# Test [3], Epoch [36/60], Loss: 1.3291
# Test [3], Epoch [38/60], Loss: 1.3956
# Test [3], Epoch [40/60], Loss: 1.3975
# Test [3], Epoch [42/60], Loss: 1.4423
# Test [3], Epoch [44/60], Loss: 1.3462
# Test [3], Epoch [46/60], Loss: 1.4033
# Test [3], Epoch [48/60], Loss: 1.3002
# Test [3], Epoch [50/60], Loss: 1.2758
# Test [3], Epoch [52/60], Loss: 1.4000
# Test [3], Epoch [54/60], Loss: 1.3681
# Test [3], Epoch [56/60], Loss: 1.3638
# Test [3], Epoch [58/60], Loss: 1.2463
# Test [3], Epoch [60/60], Loss: 1.3551
# Dev accuracy of the No.3 model on dev action samples: 28.125 %
# (528, 36)
# Test [4], Epoch [2/60], Loss: 1.3940
# Test [4], Epoch [4/60], Loss: 1.4769
# Test [4], Epoch [6/60], Loss: 1.4200
# Test [4], Epoch [8/60], Loss: 1.3573
# Test [4], Epoch [10/60], Loss: 1.4345
# Test [4], Epoch [12/60], Loss: 1.2640
# Test [4], Epoch [14/60], Loss: 1.2740
# Test [4], Epoch [16/60], Loss: 1.3362
# Test [4], Epoch [18/60], Loss: 1.2938
# Test [4], Epoch [20/60], Loss: 1.2483
# Test [4], Epoch [22/60], Loss: 1.3019
# Test [4], Epoch [24/60], Loss: 1.2038
# Test [4], Epoch [26/60], Loss: 1.1647
# Test [4], Epoch [28/60], Loss: 1.0447
# Test [4], Epoch [30/60], Loss: 1.1597
# Test [4], Epoch [32/60], Loss: 0.9157
# Test [4], Epoch [34/60], Loss: 0.9533
# Test [4], Epoch [36/60], Loss: 1.0938
# Test [4], Epoch [38/60], Loss: 0.9064
# Test [4], Epoch [40/60], Loss: 0.8793
# Test [4], Epoch [42/60], Loss: 0.7127
# Test [4], Epoch [44/60], Loss: 0.6131
# Test [4], Epoch [46/60], Loss: 0.8043
# Test [4], Epoch [48/60], Loss: 0.5692
# Test [4], Epoch [50/60], Loss: 0.5882
# Test [4], Epoch [52/60], Loss: 0.4602
# Test [4], Epoch [54/60], Loss: 0.5829
# Test [4], Epoch [56/60], Loss: 0.4776
# Test [4], Epoch [58/60], Loss: 0.2835
# Test [4], Epoch [60/60], Loss: 0.3060
# Dev accuracy of the No.4 model on dev action samples: 25.0 %
# (528, 36)
# Test [5], Epoch [2/60], Loss: 1.4555
# Test [5], Epoch [4/60], Loss: 1.5026
# Test [5], Epoch [6/60], Loss: 1.3859
# Test [5], Epoch [8/60], Loss: 1.1683
# Test [5], Epoch [10/60], Loss: 0.4041
# Test [5], Epoch [12/60], Loss: 0.0835
# Test [5], Epoch [14/60], Loss: 0.0184
# Test [5], Epoch [16/60], Loss: 0.0095
# Test [5], Epoch [18/60], Loss: 0.0064
# Test [5], Epoch [20/60], Loss: 0.0032
# Test [5], Epoch [22/60], Loss: 0.0026
# Test [5], Epoch [24/60], Loss: 0.0020
# Test [5], Epoch [26/60], Loss: 0.0017
# Test [5], Epoch [28/60], Loss: 0.0016
# Test [5], Epoch [30/60], Loss: 0.0012
# Test [5], Epoch [32/60], Loss: 0.0012
# Test [5], Epoch [34/60], Loss: 0.0013
# Test [5], Epoch [36/60], Loss: 0.0011
# Test [5], Epoch [38/60], Loss: 0.0009
# Test [5], Epoch [40/60], Loss: 0.0009
# Test [5], Epoch [42/60], Loss: 0.0007
# Test [5], Epoch [44/60], Loss: 0.0006
# Test [5], Epoch [46/60], Loss: 0.0005
# Test [5], Epoch [48/60], Loss: 0.0006
# Test [5], Epoch [50/60], Loss: 0.0006
# Test [5], Epoch [52/60], Loss: 0.0005
# Test [5], Epoch [54/60], Loss: 0.0004
# Test [5], Epoch [56/60], Loss: 0.0004
# Test [5], Epoch [58/60], Loss: 0.0004
# Test [5], Epoch [60/60], Loss: 0.0004
# Dev accuracy of the No.5 model on dev action samples: 93.75 %
# Choose No.5 model as test model with 93.75 % Dev accuracy.
# Final accuracy is 87.5 %
# [Cost Time]: total - 0:26:08.599176s, each - 0:05:13.719835s
# -----------------------------------------------------
# TypeError           Traceback (most recent call last)
# <ipython-input-12-c84cae59f145> in <module>
#       7 end = datetime.datetime.now()
#       8 print('[Cost Time]: total - {}s, each - {}s'.format(end-start, (end-start)/test_num))
# ----> 9 print('{} times average accuracy - {}%'.format(test_num, max(test_accuracies)))
#
# TypeError: '>' not supported between instances of 'NoneType' and 'NoneType'

# %%
print(test_accuracies)
# Out:
# [None, None, None, None, None]
